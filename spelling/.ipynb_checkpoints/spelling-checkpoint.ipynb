# %% [markdown]
# # Морфология 2
# В данном ноутбуке находится задание на триграммы и словарь. В качестве текста будем использовать томик войны и мира: https://goo.gl/qcVTLE
#
# Для начала напомним некоторые полезные инструменты на питоне

# %% [markdown]
# ## 1. Инструменты

# %% [markdown]
# ### 1.1. Регулярные выражения
# Исчерпывающий пост https://habr.com/ru/post/349860/

# %%
import re

# С помощью рег. выражения можно искать, заменять и сентезировать строки по шаблонам
# Парочка простых примеров
numbers = re.findall(r'\d+', r'There is some numbers: 49 and 432')
print(u'Находим числа в строке: ', numbers)

print(u'Простенький токенизатор: ', re.sub('[,\.?!]',' ','How, to? split. text!').split())

print(u'Еще один токенизатор: ', re.split(r'\W+', 'How, to? split. text! Again'))

# в качестве тренировки придумайте свой токенизатор в случае, когда из текста нужно получить только русские слова.
# Out:
# Находим числа в строке:  ['49', '432']
# Простенький токенизатор:  ['How', 'to', 'split', 'text']
# Еще один токенизатор:  ['How', 'to', 'split', 'text', 'Again']

# %% [markdown]
# ### 1.2. Чтение файлов
# Чтобы не мучится самим с кодировками, приведем способ чтения файла корпуса.

# %%
import io
import razdel
wordlist = None

with io.open('war_and_piece.txt', "r") as text_file:
    text = text_file.read()
    wordlist = razdel.tokenize(text.lower())
    # wordlist = Здесь заиспользуем токенизатор. Также приведем все слова к нижнему регистру.

# %% [markdown]
# ### 1.3. ООП
# В питоне можно создавать свои классы, скорее всего нам понадобится класс для хранения бора

# %%
class Trie:
    def __init__(self):
        self.children = {}
        self.is_word = False
    
    def add(self, word):
        if not word:
            print('Аргумент не является словом')
            
        head, *tail = word
        
        if head not in self.children:
            self.children[head] = Trie()
        
        node = self.children[head]
        
        if tail:
            node.add(tail)
        else:
            self.is_word = True

# %%
trie = Trie()
trie.add('he')
trie.add('she')
trie.add('his')
trie.add('hers')
trie.children
# Out:
# {'h': <__main__.Trie at 0x1cd21f0a700>, 's': <__main__.Trie at 0x1cd21f0aaf0>}

# %% [markdown]
# ### 1.4. pyplot
# Довольно часто приходится построить какие-нибудт графики и гистограммы для изучения данных, с которыми придется работать. Для этого в питоне есть удобнейший модуль для этого - pyplot. Туториал: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html

# %%
#!pip install matplotlib # Установка модуля
import matplotlib.pyplot as plt
# команда чтобы картинки рисовались прямо в ноутбуке
# %matplotlib inline

# %%
# Посмотрим на график функции x^2
data = [i * i for i in range(100)]
plt.plot(data)

# %%
# и распределение по значениям
plt.hist(data)
# Out:
# (array([32., 13., 10.,  8.,  8.,  6.,  6.,  6.,  5.,  6.]),
#  array([   0. ,  980.1, 1960.2, 2940.3, 3920.4, 4900.5, 5880.6, 6860.7,
#         7840.8, 8820.9, 9801. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Также полезная команда для подсчета времения выполнеия в ячейке

# %%
# %%time
res = 0
for i in range(int(1e8)):
    res += 1
# Out:
# Wall time: 8.87 s

# %% [markdown]
# ## 2. Задание
# Собственно теперь нам потребуется написать подсчет триграмм и бор для словаря, чтобы реализовать простенькую систему исправления ошибок.

# %% [markdown]
# ### 2.1. Триграммы
# Для начала получим словарь триграмма - её кол-во в тексте, не забывая о начале и конце слова.
#
# Далее можно построить гистограмму на кол-во вхождений триграмм, и посмотреть самые частые и какая частота у каких-нибудь заведомо странных, например: 'чгк', 'шкя' и подобные. Из полученных данных придумать эвристику, как считать слово с опечаткой. Проверить эвристику по словарю.

# %%
import io
import razdel
wordlist = None

with io.open('war_and_piece.txt', "r") as text_file:
    text = text_file.read()
    wordlist = list(razdel.tokenize(text.lower()))

# %%
def build_corpus_trigrams(words):
    trigrams_and_freq = {}
    
    for word in words:
        marked_word = '##' + word.text + '##'
        
        for char in range(len(marked_word) - 2):
            trigram = marked_word[char: char + 3]
            
            if trigram in trigrams_and_freq:
                trigrams_and_freq[trigram] += 1
            else:
                trigrams_and_freq[trigram] = 1
    
    return trigrams_and_freq

        
def is_error(word, trigrams_and_freq):
    marked_word = '##' + word.text + '##' 
    
    errors = []
    # будем учитывать две триграммы
    for char in range(1, len(marked_word) - 2):
        first_trigram = marked_word[char - 1: char + 2]
        second_trigram = marked_word[char: char + 3]
        votes = 0
        
        if first_trigram in trigrams_and_freq and trigrams_and_freq[first_trigram] > 2:
            votes += 0
        else:
            votes += 1
        
        if second_trigram in trigrams_and_freq and trigrams_and_freq[second_trigram] > 2:
            votes += 0
        else:
            votes += 1
            
        if votes == 2: 
            errors.append(first_trigram)
            errors.append(second_trigram)
            
    if errors:
        return set(errors)
    else:
        return False

# %%
def print_errors(words):
    trigram_dict = build_corpus_trigrams(words)
    for word in words:
        result = is_error(word, trigram_dict)
        if result:
            print('Cлово ->', word.text, '| Возможные ошибки ->', result)

# %%
print_errors(wordlist)
# Out:
# Cлово -> lucques | Возможные ошибки -> {'luc', 'ucq'}
# Cлово -> atrocites | Возможные ошибки -> {'oci', 'roc'}
# Cлово -> генуа | Возможные ошибки -> {'уа#', 'нуа'}
# Cлово -> лукка | Возможные ошибки -> {'кка', 'укк'}
# Cлово -> июле | Возможные ошибки -> {'юле', 'июл', '#ию'}
# Cлово -> virulente | Возможные ошибки -> {'iru', 'vir'}
# Cлово -> insipides | Возможные ошибки -> {'sip', 'ipi'}
# Cлово -> a-t-on | Возможные ошибки -> {'-on', 't-o'}
# Cлово -> novosiizoff | Возможные ошибки -> {'izo', 'nov', 'sii', 'iiz', 'ovo'}
# Cлово -> a-t-on | Возможные ошибки -> {'-on', 't-o'}
# Cлово -> отжившим | Возможные ошибки -> {'тжи', 'отж'}
# Cлово -> гидру | Возможные ошибки -> {'гид', 'идр'}
# Cлово -> самоотвержения | Возможные ошибки -> {'оот', 'моо'}
# Cлово -> montmorency | Возможные ошибки -> {'ntm', 'tmo', 'ncy', 'cy#'}
# Cлово -> rohans | Возможные ошибки -> {'roh', 'oha'}
# Cлово -> монморанси | Возможные ошибки -> {'онм', 'нмо'}
# Cлово -> abbe | Возможные ошибки -> {'abb', 'bbe'}
# Cлово -> императрица-мать | Возможные ошибки -> {'а-м', 'ца-'}
# Cлово -> funke | Возможные ошибки -> {'fun', 'unk'}
# Cлово -> императрице-матери | Возможные ошибки -> {'е-м', 'це-'}
# Cлово -> безапелляционно | Возможные ошибки -> {'елл', 'лля'}
# Cлово -> lafater | Возможные ошибки -> {'afa', 'laf', 'fat'}
# Cлово -> 40.000 | Возможные ошибки -> {'0.0', '.00', '40.'}
# Cлово -> покой-ер-п | Возможные ошибки -> {'й-е', '-п#', 'р-п', '-ер'}
# Cлово -> шифре | Возможные ошибки -> {'шиф', 'ифр'}
# Cлово -> seduisante | Возможные ошибки -> {'sed', 'edu'}
# Cлово -> полуоткрытый | Возможные ошибки -> {'уот', 'луо'}
# Cлово -> attifee | Возможные ошибки -> {'fee', 'ife'}
# Cлово -> сыграйте | Возможные ошибки -> {'ыгр', 'сыг'}
# Cлово -> tranquille | Возможные ошибки -> {'anq', 'nqu'}
# Cлово -> красавица-княжна | Возможные ошибки -> {'-кн', 'а-к', 'ца-'}
# Cлово -> сверхъестественно-прекрасное | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> сверхъестественно | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> parfait | Возможные ошибки -> {'arf', 'rfa'}
# Cлово -> b | Возможные ошибки -> {'b##', '#b#'}
# Cлово -> ростбиф | Возможные ошибки -> {'иф#', 'биф'}
# Cлово -> hippolyte | Возможные ошибки -> {'yte', 'hip', 'oly', 'lyt', 'ipp'}
# Cлово -> сестрою-красавицей | Возможные ошибки -> {'ю-к', 'ою-'}
# Cлово -> брюзгливость | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> cuisse | Возможные ошибки -> {'cui', '#cu'}
# Cлово -> nymphe | Возможные ошибки -> {'#ny', 'phe', 'ymp', 'mph', 'nym'}
# Cлово -> нимфы | Возможные ошибки -> {'имф', 'мфы'}
# Cлово -> george | Возможные ошибки -> {'eor', 'geo'}
# Cлово -> мадмуазель | Возможные ошибки -> {'адм', 'дму'}
# Cлово -> жорж | Возможные ошибки -> {'жор', '#жо'}
# Cлово -> koutouzoff | Возможные ошибки -> {'ouz', 'uzo'}
# Cлово -> жорж | Возможные ошибки -> {'жор', '#жо'}
# Cлово -> peuples | Возможные ошибки -> {'upl', 'eup'}
# Cлово -> lucques | Возможные ошибки -> {'luc', 'ucq'}
# Cлово -> лукки | Возможные ошибки -> {'кки', 'укк'}
# Cлово -> изъявляют | Возможные ошибки -> {'изъ', 'зъя'}
# Cлово -> guai | Возможные ошибки -> {'uai', 'gua'}
# Cлово -> elisabeth | Возможные ошибки -> {'eth', 'th#'}
# Cлово -> subissent | Возможные ошибки -> {'ubi', 'bis'}
# Cлово -> bourbons | Возможные ошибки -> {'urb', 'rbo'}
# Cлово -> usurpateur | Возможные ошибки -> {'urp', '#us', 'usu', 'rpa', 'pat'}
# Cлово -> azur | Возможные ошибки -> {'#az', 'zur', 'azu'}
# Cлово -> геральдических | Возможные ошибки -> {'дич', 'ьди'}
# Cлово -> gloire | Возможные ошибки -> {'glo', '#gl', 'loi'}
# Cлово -> marietyr | Возможные ошибки -> {'yr#', 'tyr', 'ety'}
# Cлово -> злоупотребления | Возможные ошибки -> {'лоу', 'оуп'}
# Cлово -> social | Возможные ошибки -> {'oci', 'cia', 'soc'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> яффе | Возможные ошибки -> {'#яф', 'яфф'}
# Cлово -> anecdote | Возможные ошибки -> {'ane', 'ecd', 'dot', 'nec', 'cdo'}
# Cлово -> moscovite | Возможные ошибки -> {'cov', 'ovi'}
# Cлово -> excusez | Возможные ошибки -> {'xcu', 'cus'}
# Cлово -> pied | Возможные ошибки -> {'ed#', 'ied'}
# Cлово -> незапно | Возможные ошибки -> {'апн', 'пно'}
# Cлово -> неуклюж | Возможные ошибки -> {'юж#', 'люж'}
# Cлово -> па-звольте | Возможные ошибки -> {'-зв', 'а-з', 'па-'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'a-f', '-fa', '-a-', 't-a'}
# Cлово -> innocent | Возможные ошибки -> {'noc', 'oce'}
# Cлово -> regnant | Возможные ошибки -> {'egn', 'gna'}
# Cлово -> гувернером-аббатом | Возможные ошибки -> {'-аб', 'м-а'}
# Cлово -> свяжи | Возможные ошибки -> {'вяж', 'яжи'}
# Cлово -> образцом | Возможные ошибки -> {'азц', 'зцо'}
# Cлово -> июньская | Возможные ошибки -> {'ньс', 'июн', 'юнь', '#ию'}
# Cлово -> бесхарактерными | Возможные ошибки -> {'сха', 'есх'}
# Cлово -> бретёр | Возможные ошибки -> {'тёр', 'ёр#', 'етё'}
# Cлово -> *** | Возможные ошибки -> {'*##', '**#', '***', '##*', '#**'}
# Cлово -> радзивилов | Возможные ошибки -> {'адз', 'дзи'}
# Cлово -> цуги | Возможные ошибки -> {'#цу', 'цуг'}
# Cлово -> камчатные | Возможные ошибки -> {'амч', 'мча'}
# Cлово -> подзывал | Возможные ошибки -> {'одз', 'дзы'}
# Cлово -> longtemps | Возможные ошибки -> {'ong', 'ngt', 'gte'}
# Cлово -> razoumowsky | Возможные ошибки -> {'oum', 'mow', 'sky', 'ows', 'raz', 'wsk', 'ky#', 'umo', 'azo'}
# Cлово -> паузе | Возможные ошибки -> {'пау', 'ауз'}
# Cлово -> медведю | Возможные ошибки -> {'едю', 'дю#'}
# Cлово -> lorrain | Возможные ошибки -> {'lor', 'orr'}
# Cлово -> гостьи-барышни | Возможные ошибки -> {'ьи-', 'и-б'}
# Cлово -> соня-племянница | Возможные ошибки -> {'ня-', '-пл', 'я-п'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ю-б', 'ью-'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ю-б', 'ью-'}
# Cлово -> секреты-то | Возможные ошибки -> {'ы-т', 'ты-'}
# Cлово -> шепчущая | Возможные ошибки -> {'пчу', 'епч'}
# Cлово -> глубже | Возможные ошибки -> {'убж', 'бже'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'#с-', 'с-г'}
# Cлово -> жанлис | Возможные ошибки -> {'нли', 'анл'}
# Cлово -> lorrain | Возможные ошибки -> {'lor', 'orr'}
# Cлово -> humanum | Возможные ошибки -> {'num', 'anu'}
# Cлово -> stupide | Возможные ошибки -> {'#st', 'tup', 'stu', 'upi'}
# Cлово -> salut | Возможные ошибки -> {'alu', 'lut'}
# Cлово -> княжен-племянниц | Возможные ошибки -> {'-пл', 'ен-', 'н-п'}
# Cлово -> combien | Возможные ошибки -> {'omb', 'mbi'}
# Cлово -> зачумленный | Возможные ошибки -> {'чум', 'умл'}
# Cлово -> jacquot | Возможные ошибки -> {'jac', 'acq'}
# Cлово -> jacquot | Возможные ошибки -> {'jac', 'acq'}
# Cлово -> ахросимову | Возможные ошибки -> {'ахр', 'хро'}
# Cлово -> dragon | Возможные ошибки -> {'gon', 'ago'}
# Cлово -> honorable | Возможные ошибки -> {'ono', 'nor'}
# Cлово -> альфонс | Возможные ошибки -> {'ьфо', 'льф'}
# Cлово -> карлыч | Возможные ошибки -> {'лыч', 'рлы'}
# Cлово -> нет-с | Возможные ошибки -> {'т-с', 'ет-'}
# Cлово -> двухсот | Возможные ошибки -> {'ухс', 'хсо'}
# Cлово -> двухсот | Возможные ошибки -> {'ухс', 'хсо'}
# Cлово -> roverbe | Возможные ошибки -> {'rbe', 'erb'}
# Cлово -> хозяева | Возможные ошибки -> {'яев', 'зяе'}
# Cлово -> razoumovsky | Возможные ошибки -> {'oum', 'sky', 'ovs', 'mov', 'vsk', 'raz', 'ky#', 'umo', 'azo'}
# Cлово -> яхонтовые | Возможные ошибки -> {'яхо', '#ях'}
# Cлово -> резче | Возможные ошибки -> {'зче', 'езч'}
# Cлово -> rabattu | Возможные ошибки -> {'ttu', 'tu#'}
# Cлово -> ъ | Возможные ошибки -> {'##ъ', 'ъ##', '#ъ#'}
# Cлово -> ь | Возможные ошибки -> {'##ь', '#ь#'}
# Cлово -> затэм | Возможные ошибки -> {'атэ', 'эм#', 'тэм'}
# Cлово -> импэ | Возможные ошибки -> {'пэ#', 'мпэ'}
# Cлово -> знаэ | Возможные ошибки -> {'аэ#', 'наэ'}
# Cлово -> манифэ | Возможные ошибки -> {'ифэ', 'фэ#'}
# Cлово -> нэ | Возможные ошибки -> {'#нэ', 'нэ#'}
# Cлово -> можэ | Возможные ошибки -> {'жэ#', 'ожэ'}
# Cлово -> смотрэт | Возможные ошибки -> {'рэт', 'трэ', 'эт#'}
# Cлово -> бэ | Возможные ошибки -> {'бэ#', '#бэ'}
# Cлово -> зачэм | Возможные ошибки -> {'эм#', 'ачэ', 'чэм'}
# Cлово -> поощрением | Возможные ошибки -> {'щре', 'оощ', 'ощр'}
# Cлово -> proverbe | Возможные ошибки -> {'rbe', 'erb'}
# Cлово -> послэ | Возможные ошибки -> {'лэ#', 'слэ'}
# Cлово -> днэ | Возможные ошибки -> {'днэ', 'нэ#'}
# Cлово -> умэ | Возможные ошибки -> {'мэ#', 'умэ'}
# Cлово -> р-р-рэ | Возможные ошибки -> {'-рэ', 'рэ#'}
# Cлово -> своэ | Возможные ошибки -> {'воэ', 'оэ#'}
# Cлово -> импэ | Возможные ошибки -> {'пэ#', 'мпэ'}
# Cлово -> всэ | Возможные ошибки -> {'сэ#', 'всэ'}
# Cлово -> й | Возможные ошибки -> {'##й', '#й#'}
# Cлово -> будэ | Возможные ошибки -> {'дэ#', 'удэ'}
# Cлово -> напыщенно | Возможные ошибки -> {'ыще', 'пыщ'}
# Cлово -> настоящэ | Возможные ошибки -> {'ящэ', 'щэ#'}
# Cлово -> й | Возможные ошибки -> {'##й', '#й#'}
# Cлово -> человэк | Возможные ошибки -> {'вэк', 'овэ'}
# Cлово -> сыграла | Возможные ошибки -> {'ыгр', 'сыг'}
# Cлово -> у-у-у | Возможные ошибки -> {'-у#', 'у-у', '-у-', '#у-'}
# Cлово -> горьче | Возможные ошибки -> {'рьч', 'ьче'}
# Cлово -> вот-вот | Возможные ошибки -> {'т-в', 'от-'}
# Cлово -> вежливостью | Возможные ошибки -> {'ежл', 'жли'}
# Cлово -> молодецки-хитрою | Возможные ошибки -> {'-хи', 'и-х'}
# Cлово -> граф-то | Возможные ошибки -> {'аф-', 'ф-т'}
# Cлово -> est-ce-pas | Возможные ошибки -> {'e-p', '-pa'}
# Cлово -> шифоньерок | Возможные ошибки -> {'ифо', 'шиф'}
# Cлово -> шкапчиков | Возможные ошибки -> {'апч', 'пчи'}
# Cлово -> ширм | Возможные ошибки -> {'рм#', 'ирм'}
# Cлово -> нагло-шутливо | Возможные ошибки -> {'-шу', 'о-ш'}
# Cлово -> всём | Возможные ошибки -> {'сём', 'ём#'}
# Cлово -> clair | Возможные ошибки -> {'#cl', 'cla'}
# Cлово -> онуфриичем | Возможные ошибки -> {'уфр', 'нуф'}
# Cлово -> sophie | Возможные ошибки -> {'sop', 'oph'}
# Cлово -> подзывая | Возможные ошибки -> {'одз', 'дзы'}
# Cлово -> agonie | Возможные ошибки -> {'gon', 'ago'}
# Cлово -> полуосвещенную | Возможные ошибки -> {'уос', 'луо'}
# Cлово -> docteur | Возможные ошибки -> {'oct', 'doc'}
# Cлово -> a-t-il | Возможные ошибки -> {'-il', 't-i'}
# Cлово -> demi-heure | Возможные ошибки -> {'-he', 'i-h', 'mi-'}
# Cлово -> церкви | Возможные ошибки -> {'кви', 'ркв'}
# Cлово -> церкви | Возможные ошибки -> {'кви', 'ркв'}
# Cлово -> француз-доктор | Возможные ошибки -> {'уз-', 'з-д'}
# Cлово -> резче | Возможные ошибки -> {'зче', 'езч'}
# Cлово -> необычайно-широким | Возможные ошибки -> {'-ши', 'о-ш'}
# Cлово -> неуклюжее | Возможные ошибки -> {'юже', 'люж'}
# Cлово -> щипанье | Возможные ошибки -> {'щип', '#щи'}
# Cлово -> assoupi | Возможные ошибки -> {'pi#', 'upi'}
# Cлово -> туалетах | Возможные ошибки -> {'уал', 'туа'}
# Cлово -> жемчугах | Возможные ошибки -> {'мчу', 'чуг', 'емч'}
# Cлово -> толще | Возможные ошибки -> {'лще', 'олщ'}
# Cлово -> conjure | Возможные ошибки -> {'jur', 'nju'}
# Cлово -> soutndra | Возможные ошибки -> {'utn', 'tnd'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> мадмуазель | Возможные ошибки -> {'адм', 'дму'}
# Cлово -> алгебры | Возможные ошибки -> {'геб', 'алг', 'лге'}
# Cлово -> ногтем | Возможные ошибки -> {'огт', 'гте'}
# Cлово -> элоизы | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> старчески-едким | Возможные ошибки -> {'и-е', '-ед'}
# Cлово -> abc | Возможные ошибки -> {'abc', 'bc#'}
# Cлово -> стерпится-слюбится | Возможные ошибки -> {'ся-', 'я-с'}
# Cлово -> элоиза | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> effrayante | Возможные ошибки -> {'aya', 'yan'}
# Cлово -> indissolubles | Возможные ошибки -> {'olu', 'lub'}
# Cлово -> revolte | Возможные ошибки -> {'olt', 'vol'}
# Cлово -> puis-je | Возможные ошибки -> {'s-j', '-je', 'is-'}
# Cлово -> 211 | Возможные ошибки -> {'211', '11#', '#21'}
# Cлово -> lui-meme | Возможные ошибки -> {'i-m', 'ui-'}
# Cлово -> corsicain | Возможные ошибки -> {'ors', 'rsi'}
# Cлово -> tout-р | Возможные ошибки -> {'t-р', '-р#'}
# Cлово -> enthousiasme | Возможные ошибки -> {'tho', 'hou'}
# Cлово -> noblesse | Возможные ошибки -> {'obl', 'nob'}
# Cлово -> vingt | Возможные ошибки -> {'ngt', 'gt#'}
# Cлово -> par-dessus | Возможные ошибки -> {'sus', 'ssu', 'ar-', 'r-d'}
# Cлово -> legitime | Возможные ошибки -> {'egi', 'leg', 'git'}
# Cлово -> consequent | Возможные ошибки -> {'seq', 'equ'}
# Cлово -> legs | Возможные ошибки -> {'egs', 'leg', 'gs#'}
# Cлово -> amuse | Возможные ошибки -> {'amu', 'mus'}
# Cлово -> observer | Возможные ошибки -> {'#ob', 'obs'}
# Cлово -> paru | Возможные ошибки -> {'ru#', 'aru'}
# Cлово -> amuse | Возможные ошибки -> {'amu', 'mus'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> projet | Возможные ошибки -> {'oje', 'roj'}
# Cлово -> anatole | Возможные ошибки -> {'ato', 'tol'}
# Cлово -> tombe | Возможные ошибки -> {'tom', 'omb'}
# Cлово -> choix | Возможные ошибки -> {'oix', 'hoi'}
# Cлово -> cru | Возможные ошибки -> {'cru', 'ru#'}
# Cлово -> sujet | Возможные ошибки -> {'uje', 'suj'}
# Cлово -> bavardage | Возможные ошибки -> {'rda', 'dag'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> admirable | Возможные ошибки -> {'mir', 'dmi', 'adm'}
# Cлово -> m-elle | Возможные ошибки -> {'m-e', '-el'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> поэзии | Возможные ошибки -> {'эзи', 'оэз'}
# Cлово -> свежо | Возможные ошибки -> {'жо#', 'ежо'}
# Cлово -> дочери-невесты | Возможные ошибки -> {'ри-', 'и-н'}
# Cлово -> 13 | Возможные ошибки -> {'13#', '3##', '#13'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> devrai-je | Возможные ошибки -> {'ai-', 'i-j', '-je'}
# Cлово -> osais | Возможные ошибки -> {'#os', 'osa'}
# Cлово -> avions | Возможные ошибки -> {'vio', 'avi'}
# Cлово -> ayant | Возможные ошибки -> {'#ay', 'aya', 'yan'}
# Cлово -> inspire | Возможные ошибки -> {'spi', 'pir', 'nsp'}
# Cлово -> opinion | Возможные ошибки -> {'#op', 'opi'}
# Cлово -> royaume | Возможные ошибки -> {'aum', 'yau'}
# Cлово -> aura-t-il | Возможные ошибки -> {'-il', 't-i'}
# Cлово -> subir | Возможные ошибки -> {'bir', 'ubi'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> inutile | Возможные ошибки -> {'inu', 'nut'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'a-f', '-fa', '-a-', 't-a'}
# Cлово -> chretnne | Возможные ошибки -> {'tnn', 'etn'}
# Cлово -> evangile | Возможные ошибки -> {'ngi', 'gil'}
# Cлово -> ceux-la | Возможные ошибки -> {'x-l', '-la', 'ux-'}
# Cлово -> mysterux | Возможные ошибки -> {'eru', 'rux'}
# Cлово -> etudr | Возможные ошибки -> {'tud', 'etu'}
# Cлово -> principes | Возможные ошибки -> {'pes', 'ipe'}
# Cлово -> ici-bas | Возможные ошибки -> {'-ba', 'i-b', 'ci-'}
# Cлово -> persuadons-nous | Возможные ошибки -> {'sua', 'uad', 'rsu'}
# Cлово -> agreable | Возможные ошибки -> {'rea', 'eab'}
# Cлово -> rejette | Возможные ошибки -> {'rej', 'eje'}
# Cлово -> approfondir | Возможные ошибки -> {'rof', 'ofo'}
# Cлово -> plutot | Возможные ошибки -> {'tot', 'uto', 'lut'}
# Cлово -> projet | Возможные ошибки -> {'oje', 'roj'}
# Cлово -> tout-puissant | Возможные ошибки -> {'t-p', '-pu'}
# Cлово -> inquieter | Возможные ошибки -> {'inq', 'nqu'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> lequel | Возможные ошибки -> {'equ', 'leq'}
# Cлово -> sanglots | Возможные ошибки -> {'glo', 'lot'}
# Cлово -> 13-го | Возможные ошибки -> {'13-', '#13', '3-г'}
# Cлово -> juger | Возможные ошибки -> {'jug', 'uge'}
# Cлово -> дюссековой | Возможные ошибки -> {'дюс', 'юсс'}
# Cлово -> exerce | Возможные ошибки -> {'exe', 'xer'}
# Cлово -> doucement | Возможные ошибки -> {'cem', 'uce'}
# Cлово -> surprendre | Возможные ошибки -> {'urp', 'rpr'}
# Cлово -> belle-soeur | Возможные ошибки -> {'le-', 'e-s', '-so', 'soe'}
# Cлово -> мамзель | Возможные ошибки -> {'амз', 'мзе'}
# Cлово -> одынцова | Возможные ошибки -> {'дын', 'ынц'}
# Cлово -> oia | Возможные ошибки -> {'#oi', 'oia', 'ia#'}
# Cлово -> брюзгливым | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> сафьяном | Возможные ошибки -> {'фья', 'саф', 'афь'}
# Cлово -> эдак | Возможные ошибки -> {'дак', '#эд', 'эда'}
# Cлово -> южная | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> malbroug | Возможные ошибки -> {'oug', 'bro', 'lbr', 'ug#', 'alb'}
# Cлово -> рюрика | Возможные ошибки -> {'рюр', 'юри'}
# Cлово -> хофс-кригс-вурст-шнапс-рат | Возможные ошибки -> {'-шн', 'апс', 'т-ш', 'пс-', 'гс-', 'ст-', 'вур', '-ву', 'с-р', 'с-в'}
# Cлово -> хофс-кригс-вурст-раты | Возможные ошибки -> {'гс-', 'ст-', 'вур', 'т-р', '-ву', 'с-в'}
# Cлово -> новый-йорк | Возможные ошибки -> {'-йо', 'й-й', 'ый-'}
# Cлово -> admirateur | Возможные ошибки -> {'mir', 'dmi', 'adm'}
# Cлово -> goujat | Возможные ошибки -> {'jat', 'uja'}
# Cлово -> холопского | Возможные ошибки -> {'пск', 'опс'}
# Cлово -> покоях | Возможные ошибки -> {'коя', 'оях'}
# Cлово -> привыкшей | Возможные ошибки -> {'кше', 'ыкш'}
# Cлово -> слёз | Возможные ошибки -> {'лёз', 'слё', 'ёз#'}
# Cлово -> zouboff | Возможные ошибки -> {'bof', 'ubo'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'#с-', 'с-г'}
# Cлово -> ломбардный | Возможные ошибки -> {'омб', 'мба'}
# Cлово -> bt | Возможные ошибки -> {'#bt', 'bt#'}
# Cлово -> 11-го | Возможные ошибки -> {'1-г', '11-', '#11'}
# Cлово -> как-будто | Возможные ошибки -> {'-бу', 'к-б'}
# Cлово -> бесшоссейной | Возможные ошибки -> {'сшо', 'шос'}
# Cлово -> цугом | Возможные ошибки -> {'#цу', 'цуг'}
# Cлово -> кроатов | Возможные ошибки -> {'оат', 'роа'}
# Cлово -> рявкнул | Возможные ошибки -> {'явк', 'вкн'}
# Cлово -> 217 | Возможные ошибки -> {'17#', '217', '#21'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'чь-', '-в-', 'в-т', 'ь-в'}
# Cлово -> субалтерн-офицеру | Возможные ошибки -> {'н-о', 'рн-'}
# Cлово -> субалтерн-офицер | Возможные ошибки -> {'н-о', 'рн-'}
# Cлово -> федешоу | Возможные ошибки -> {'оу#', 'шоу'}
# Cлово -> турции | Возможные ошибки -> {'рци', 'урц'}
# Cлово -> солдат-песенников | Возможные ошибки -> {'ат-', 'т-п'}
# Cлово -> пляшущего | Возможные ошибки -> {'ляш', 'шущ', 'яшу'}
# Cлово -> буйному | Возможные ошибки -> {'уйн', 'буй'}
# Cлово -> фараон | Возможные ошибки -> {'аон', 'рао'}
# Cлово -> дай-ка | Возможные ошибки -> {'ай-', 'й-к'}
# Cлово -> vollkommen | Возможные ошибки -> {'llk', 'lko', 'kom'}
# Cлово -> zusammengehaltene | Возможные ошибки -> {'usa', 'sam', 'eha', 'zus', 'amm', 'geh'}
# Cлово -> krafte | Возможные ошибки -> {'kra', 'raf', '#kr'}
# Cлово -> nahe | Возможные ошибки -> {'nah', 'ahe'}
# Cлово -> angreifen | Возможные ошибки -> {'eif', 'ife'}
# Cлово -> beiden | Возможные ошибки -> {'bei', 'eid'}
# Cлово -> uferien | Возможные ошибки -> {'ufe', '#uf'}
# Cлово -> bleiben | Возможные ошибки -> {'eib', 'ibe'}
# Cлово -> augenblick | Возможные ошибки -> {'aug', 'nbl', 'uge', 'enb'}
# Cлово -> ubersetzen | Возможные ошибки -> {'ube', 'set', 'tze', 'zen', 'rse', 'etz', '#ub'}
# Cлово -> communikations-linie | Возможные ошибки -> {'-li', 'nik', 'kat', 'mun', 'ika', 's-l', 'mmu'}
# Cлово -> unterhalb | Возможные ошибки -> {'b##', 'lb#', 'erh', 'rha', 'alb'}
# Cлово -> solche | Возможные ошибки -> {'lch', 'olc'}
# Cлово -> zeitpunkt | Возможные ошибки -> {'zei', 'pun', 'itp', 'tpu', 'nkt', '#ze', 'unk', 'kt#'}
# Cлово -> kaiserlich-ruseische | Возможные ошибки -> {'#ka', 'kai', 'h-r', '-ru', 'ch-'}
# Cлово -> ausgerustet | Возможные ошибки -> {'sge', 'usg'}
# Cлово -> muthig | Возможные ошибки -> {'mut', 'uth'}
# Cлово -> entgegenharren | Возможные ошибки -> {'ntg', 'enh', 'nha', 'tge'}
# Cлово -> sodann | Возможные ошибки -> {'sod', 'oda'}
# Cлово -> gemeinschaftlich | Возможные ошибки -> {'ftl', 'tli'}
# Cлово -> moglichkeit | Возможные ошибки -> {'ogl', 'kei', 'mog', 'chk', 'gli', 'hke'}
# Cлово -> schicksal | Возможные ошибки -> {'cks', 'ick', 'hic', 'ksa'}
# Cлово -> zuzubereiten | Возможные ошибки -> {'ube', 'uzu', 'zub', 'zuz'}
# Cлово -> коммуникационную | Возможные ошибки -> {'мму', 'омм'}
# Cлово -> товарищами-сослуживцами | Возможные ошибки -> {'и-с', 'ми-'}
# Cлово -> зашибся | Возможные ошибки -> {'бся', 'ибс'}
# Cлово -> gott | Возможные ошибки -> {'ott', 'got', 'tt#'}
# Cлово -> garcon | Возможные ошибки -> {'rco', 'arc'}
# Cлово -> 11 | Возможные ошибки -> {'11#', '#11'}
# Cлово -> хозяин-немец | Возможные ошибки -> {'н-н', 'ин-'}
# Cлово -> фуфайке | Возможные ошибки -> {'фуф', 'фай', 'уфа'}
# Cлово -> oestreicher | Возможные ошибки -> {'oes', '#oe'}
# Cлово -> kaiser | Возможные ошибки -> {'kai', '#ka'}
# Cлово -> немцем-хозяином | Возможные ошибки -> {'-хо', 'м-х'}
# Cлово -> welt | Возможные ошибки -> {'lt#', 'elt'}
# Cлово -> vivat | Возможные ошибки -> {'iva', 'vat'}
# Cлово -> welt | Возможные ошибки -> {'lt#', 'elt'}
# Cлово -> чикчиры | Возможные ошибки -> {'чир', 'кчи', 'икч'}
# Cлово -> кг | Возможные ошибки -> {'кг#', '#кг'}
# Cлово -> кг | Возможные ошибки -> {'кг#', '#кг'}
# Cлово -> правду-матку | Возможные ошибки -> {'ду-', 'у-м'}
# Cлово -> 23-го | Возможные ошибки -> {'#23', '23-', '3-г'}
# Cлово -> доппелькюмелем | Возможные ошибки -> {'кюм', 'ькю'}
# Cлово -> тащут | Возможные ошибки -> {'щут', 'ащу'}
# Cлово -> нут-ка | Возможные ошибки -> {'т-к', 'ут-'}
# Cлово -> полуулыбаясь | Возможные ошибки -> {'уул', 'луу'}
# Cлово -> подбадривает | Возможные ошибки -> {'бад', 'дба'}
# Cлово -> мундштука | Возможные ошибки -> {'ндш', 'дшт'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'чь-', '-в-', 'в-т', 'ь-в'}
# Cлово -> кое-где | Возможные ошибки -> {'е-г', '-гд'}
# Cлово -> hexo | Возможные ошибки -> {'xo#', 'exo', 'hex'}
# Cлово -> ламбахе | Возможные ошибки -> {'мба', 'амб'}
# Cлово -> амштетене | Возможные ошибки -> {'мшт', 'амш'}
# Cлово -> 28-го | Возможные ошибки -> {'8-г', '28-'}
# Cлово -> 30-го | Возможные ошибки -> {'#30', '30-'}
# Cлово -> ямщику | Возможные ошибки -> {'мщи', 'ямщ', '#ям'}
# Cлово -> hochgeboren | Возможные ошибки -> {'hge', 'chg', 'geb'}
# Cлово -> генерала-фельдмаршала | Возможные ошибки -> {'а-ф', '-фе', 'ла-'}
# Cлово -> циркуляр | Возможные ошибки -> {'цир', 'ирк', '#ци'}
# Cлово -> bilibine | Возможные ошибки -> {'ibi', 'lib'}
# Cлово -> colportaient | Возможные ошибки -> {'lpo', 'olp'}
# Cлово -> professe | Возможные ошибки -> {'ofe', 'rof', 'fes'}
# Cлово -> victoire | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> victorieuses | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> liebchen | Возможные ошибки -> {'bch', 'ieb', 'ebc'}
# Cлово -> врбна | Возможные ошибки -> {'врб', 'рбн'}
# Cлово -> лихтенфельс | Возможные ошибки -> {'нфе', 'енф'}
# Cлово -> echauffouree | Возможные ошибки -> {'ffo', 'fou'}
# Cлово -> дон-жуан | Возможные ошибки -> {'н-ж', 'уан', '-жу', 'жуа'}
# Cлово -> дон-жуан | Возможные ошибки -> {'н-ж', 'уан', '-жу', 'жуа'}
# Cлово -> majeste | Возможные ошибки -> {'maj', 'aje', 'jes'}
# Cлово -> deroge | Возможные ошибки -> {'rog', 'oge'}
# Cлово -> non-intervention | Возможные ошибки -> {'-in', 'n-i', 'on-'}
# Cлово -> imputer | Возможные ошибки -> {'put', 'mpu'}
# Cлово -> non-recevoir | Возможные ошибки -> {'ece', 'n-r', '-re', 'cev', 'on-'}
# Cлово -> tu | Возможные ошибки -> {'tu#', '#tu'}
# Cлово -> brunn | Возможные ошибки -> {'run', 'unn'}
# Cлово -> лш | Возможные ошибки -> {'#лш', 'лш#'}
# Cлово -> ь | Возможные ошибки -> {'##ь', '#ь#'}
# Cлово -> маршрутов | Возможные ошибки -> {'ршр', 'шру'}
# Cлово -> з-й | Возможные ошибки -> {'#з-', 'з-й'}
# Cлово -> erlaucht | Возможные ошибки -> {'rla', 'lau'}
# Cлово -> ziehen | Возможные ошибки -> {'zie', 'ehe', '#zi', 'ieh'}
# Cлово -> bosewicht | Возможные ошибки -> {'ewi', 'wic', 'sew'}
# Cлово -> wieder | Возможные ошибки -> {'wie', 'ied'}
# Cлово -> ауэсперг | Возможные ошибки -> {'уэс', 'эсп'}
# Cлово -> нынче-завтра | Возможные ошибки -> {'че-', 'е-з'}
# Cлово -> генерал-лейтенант | Возможные ошибки -> {'-ле', 'л-л'}
# Cлово -> ногти | Возможные ошибки -> {'огт', 'гти'}
# Cлово -> heroisme | Возможные ошибки -> {'ism', 'sme'}
# Cлово -> philosophiee | Возможные ошибки -> {'los', 'oso', 'hil', 'ilo', 'sop', 'oph'}
# Cлово -> дилемма | Возможные ошибки -> {'емм', 'мма'}
# Cлово -> эцельсдорфа | Возможные ошибки -> {'сдо', 'рфа', 'эце', 'орф', '#эц', 'ьсд'}
# Cлово -> transportee | Возможные ошибки -> {'spo', 'nsp'}
# Cлово -> 7-го | Возможные ошибки -> {'7-г', '#7-'}
# Cлово -> шлюхой | Возможные ошибки -> {'юхо', 'люх'}
# Cлово -> про-пус-тить | Возможные ошибки -> {'с-т', 'ус-'}
# Cлово -> вьюки | Возможные ошибки -> {'ьюк', 'юки'}
# Cлово -> шрама | Возможные ошибки -> {'шра', '#шр'}
# Cлово -> буксгевденом | Возможные ошибки -> {'ксг', 'сге', 'укс', 'гев'}
# Cлово -> четырехтысячный | Возможные ошибки -> {'ехт', 'хты'}
# Cлово -> schoenbrunn | Возможные ошибки -> {'unn', 'hoe', 'run', 'enb', 'oen', 'nbr'}
# Cлово -> avant-garde | Возможные ошибки -> {'t-g', '-ga'}
# Cлово -> sur-le-champ | Возможные ошибки -> {'-le', 'le-', 'ur-', 'r-l'}
# Cлово -> bagage | Возможные ошибки -> {'bag', 'aga', 'gag'}
# Cлово -> celui-ci | Возможные ошибки -> {'i-c', 'ui-', '-ci'}
# Cлово -> napoleon | Возможные ошибки -> {'eon', 'leo'}
# Cлово -> 4.000-ный | Возможные ошибки -> {'#4.', '-ны', '00-', '4.0', '.00', '0-н'}
# Cлово -> алмазным | Возможные ошибки -> {'алм', 'лма'}
# Cлово -> каптенармус | Возможные ошибки -> {'пте', 'апт'}
# Cлово -> глянь-ка | Возможные ошибки -> {'ь-к', 'нь-'}
# Cлово -> хранцуз-то | Возможные ошибки -> {'уз-', 'з-т'}
# Cлово -> по-хранцузски | Возможные ошибки -> {'-хр', 'о-х'}
# Cлово -> часовой-артиллерист | Возможные ошибки -> {'-ар', 'й-а'}
# Cлово -> эшелонами | Возможные ошибки -> {'эше', '#эш'}
# Cлово -> лемарруа | Возможные ошибки -> {'уа#', 'руа', 'рру'}
# Cлово -> камлотовой | Возможные ошибки -> {'мло', 'амл'}
# Cлово -> пыхтя | Возможные ошибки -> {'ыхт', 'хтя'}
# Cлово -> vaillamment | Возможные ошибки -> {'amm', 'lam'}
# Cлово -> resolument | Возможные ошибки -> {'lum', 'olu'}
# Cлово -> ceda | Возможные ошибки -> {'ced', 'eda'}
# Cлово -> штиблетах | Возможные ошибки -> {'тиб', 'шти'}
# Cлово -> оставляяй | Возможные ошибки -> {'яяй', 'яй#'}
# Cлово -> ысыо | Возможные ошибки -> {'ыо#', 'сыо'}
# Cлово -> !! | Возможные ошибки -> {'#!!', '!!#'}
# Cлово -> двухпудовая | Возможные ошибки -> {'хпу', 'ухп'}
# Cлово -> разъяренное | Возможные ошибки -> {'зъя', 'яре', 'ъяр'}
# Cлово -> подгоняя | Возможные ошибки -> {'дго', 'одг'}
# Cлово -> уцелевшие | Возможные ошибки -> {'#уц', 'уце'}
# Cлово -> солдат-артиллерист | Возможные ошибки -> {'т-а', 'ат-', '-ар'}
# Cлово -> гунтерсдорф | Возможные ошибки -> {'сдо', 'рсд'}
# Cлово -> этот-то | Возможные ошибки -> {'т-т', 'от-'}
# Cлово -> статуеобразная | Возможные ошибки -> {'уео', 'туе'}
# Cлово -> 30 | Возможные ошибки -> {'#30', '30#'}
# Cлово -> давным-давно | Возможные ошибки -> {'м-д', '-да'}
# Cлово -> 1806 | Возможные ошибки -> {'06#', '806'}
# Cлово -> vues | Возможные ошибки -> {'vue', '#vu'}
# Cлово -> minutes | Возможные ошибки -> {'min', 'inu', 'nut'}
# Cлово -> слюни | Возможные ошибки -> {'люн', 'юни'}
# Cлово -> скрып | Возможные ошибки -> {'рып', 'ып#'}
# Cлово -> заодно | Возможные ошибки -> {'зао', 'аод'}
# Cлово -> лёлины | Возможные ошибки -> {'ёли', '#лё', 'лёл'}
# Cлово -> ощутительнее | Возможные ошибки -> {'щут', '#ощ', 'ощу'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> — | Возможные ошибки -> {'—##', '##—', '#—#'}
# Cлово -> вызывающе-счастливой | Возможные ошибки -> {'ще-', 'е-с', '-сч'}
# Cлово -> 50 | Возможные ошибки -> {'#50', '##5', '50#'}
# Cлово -> brillant | Возможные ошибки -> {'bri', 'ril'}
# Cлово -> красавицы-жены | Возможные ошибки -> {'ы-ж', 'цы-'}
# Cлово -> крюк | Возможные ошибки -> {'крю', 'юк#', 'рюк'}
# Cлово -> рыхлую | Возможные ошибки -> {'хлу', 'ыхл'}
# Cлово -> прешпекту | Возможные ошибки -> {'шпе', 'ешп'}
# Cлово -> кх | Возможные ошибки -> {'кх#', '#кх'}
# Cлово -> кх | Возможные ошибки -> {'кх#', '#кх'}
# Cлово -> буфетчику | Возможные ошибки -> {'буф', 'уфе'}
# Cлово -> обжившись | Возможные ошибки -> {'обж', 'бжи'}
# Cлово -> kouraguine | Возможные ошибки -> {'agu', 'uin', 'gui'}
# Cлово -> прешпекте | Возможные ошибки -> {'шпе', 'ешп'}
# Cлово -> камзол | Возможные ошибки -> {'амз', 'мзо'}
# Cлово -> чуть-чуть | Возможные ошибки -> {'-чу', 'ь-ч'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> parfaitement | Возможные ошибки -> {'arf', 'rfa'}
# Cлово -> чудацкое | Возможные ошибки -> {'ацк', 'дац'}
# Cлово -> воля-с | Возможные ошибки -> {'я-с', 'ля-'}
# Cлово -> ха-ха-ха | Возможные ошибки -> {'а-х', 'ха-', '-ха'}
# Cлово -> один-на-один | Возможные ошибки -> {'н-н', 'а-о', '-од', 'ин-'}
# Cлово -> diablement | Возможные ошибки -> {'iab', 'dia'}
# Cлово -> кофточке | Возможные ошибки -> {'фто', 'офт'}
# Cлово -> чепце | Возможные ошибки -> {'пце', 'епц', 'чеп'}
# Cлово -> ямами | Возможные ошибки -> {'яма', '#ям'}
# Cлово -> туфли | Возможные ошибки -> {'уфл', 'туф'}
# Cлово -> арифметической | Возможные ошибки -> {'риф', 'фме', 'ифм'}
# Cлово -> oublrai | Возможные ошибки -> {'blr', 'lra'}
# Cлово -> на-цыпочках | Возможные ошибки -> {'-цы', 'а-ц'}
# Cлово -> voua | Возможные ошибки -> {'ua#', 'oua'}
# Cлово -> нюни | Возможные ошибки -> {'нюн', '#ню', 'юни'}
# Cлово -> петю | Возможные ошибки -> {'тю#', 'етю'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> миллионов-миллионов | Возможные ошибки -> {'-ми', 'в-м'}
# Cлово -> образцом | Возможные ошибки -> {'азц', 'зцо'}
# Cлово -> обзаведения | Возможные ошибки -> {'бза', 'обз'}
# Cлово -> 12-го | Возможные ошибки -> {'2-г', '12-'}
# Cлово -> 15-ти | Возможные ошибки -> {'15-', '5-т'}
# Cлово -> 15-ти | Возможные ошибки -> {'15-', '5-т'}
# Cлово -> снабженные | Возможные ошибки -> {'бже', 'абж'}
# Cлово -> пирамидкой | Возможные ошибки -> {'мид', 'идк'}
# Cлово -> петизанфан | Возможные ошибки -> {'нфа', 'анф'}
# Cлово -> ущипнуть | Возможные ошибки -> {'щип', 'ипн'}
# Cлово -> армейщина | Возможные ошибки -> {'йщи', 'ейщ'}
# Cлово -> хозяевам | Возможные ошибки -> {'яев', 'зяе'}
# Cлово -> альфонс | Возможные ошибки -> {'ьфо', 'льф'}
# Cлово -> карлычем | Возможные ошибки -> {'лыч', 'рлы'}
# Cлово -> немчура | Возможные ошибки -> {'мчу', 'чур', 'емч'}
# Cлово -> свихнул | Возможные ошибки -> {'вих', 'ихн'}
# Cлово -> дуэли | Возможные ошибки -> {'уэл', 'эли', 'дуэ'}
# Cлово -> 80-титысячной | Возможные ошибки -> {'#80', '80-'}
# Cлово -> шарфах | Возможные ошибки -> {'фах', 'рфа'}
# Cлово -> расфранченные | Возможные ошибки -> {'асф', 'сфр'}
# Cлово -> аммуницией | Возможные ошибки -> {'амм', 'мму'}
# Cлово -> флюгера | Возможные ошибки -> {'юге', 'люг', 'флю'}
# Cлово -> !! | Возможные ошибки -> {'#!!', '!!#'}
# Cлово -> самоотвержения | Возможные ошибки -> {'оот', 'моо'}
# Cлово -> !? | Возможные ошибки -> {'#!?', '!?#'}
# Cлово -> замке | Возможные ошибки -> {'амк', 'мке'}
# Cлово -> аллюра | Возможные ошибки -> {'ллю', 'люр'}
# Cлово -> шварцернберга | Возможные ошибки -> {'рнб', 'нбе'}
# Cлово -> сегодняшнего | Возможные ошибки -> {'няш', 'яшн'}
# Cлово -> chef | Возможные ошибки -> {'ef#', 'hef'}
# Cлово -> пристально-холодным | Возможные ошибки -> {'-хо', 'о-х'}
# Cлово -> 16 | Возможные ошибки -> {'#16', '16#'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> huzards | Возможные ошибки -> {'uza', 'huz', 'zar'}
# Cлово -> pavlograd | Возможные ошибки -> {'avl', 'vlo', 'ad#', 'rad', 'log'}
# Cлово -> huzards | Возможные ошибки -> {'uza', 'huz', 'zar'}
# Cлово -> pavlograd | Возможные ошибки -> {'avl', 'vlo', 'ad#', 'rad', 'log'}
# Cлово -> приученная | Возможные ошибки -> {'риу', 'иуч'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> 17-го | Возможные ошибки -> {'7-г', '17-', '#17'}
# Cлово -> 19-го | Возможные ошибки -> {'19-', '9-г'}
# Cлово -> 80-титысячная | Возможные ошибки -> {'#80', '80-'}
# Cлово -> циферблате | Возможные ошибки -> {'циф', '#ци'}
# Cлово -> обер-гофмаршалу | Возможные ошибки -> {'фма', 'офм'}
# Cлово -> rr | Возможные ошибки -> {'#rr', 'rr#'}
# Cлово -> wimpfen | Возможные ошибки -> {'pfe', 'mpf'}
# Cлово -> hohenloe | Возможные ошибки -> {'hoh', 'loe', 'ohe', 'oe#', 'nlo'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> noms | Возможные ошибки -> {'ms#', 'oms'}
# Cлово -> вимпфен | Возможные ошибки -> {'фен', 'мпф', 'пфе'}
# Cлово -> гогенлое | Возможные ошибки -> {'нло', 'енл'}
# Cлово -> пришпршипрш | Возможные ошибки -> {'шип', 'прш', 'ишп', 'шпр', 'ипр'}
# Cлово -> злоязычие | Возможные ошибки -> {'ояз', 'лоя'}
# Cлово -> аракчеев | Возможные ошибки -> {'чее', 'акч', 'кче'}
# Cлово -> riz | Возможные ошибки -> {'iz#', 'riz'}
# Cлово -> 8-м | Возможные ошибки -> {'#8-', '8-м'}
# Cлово -> wald | Возможные ошибки -> {'#wa', 'wal'}
# Cлово -> bedeckten | Возможные ошибки -> {'ckt', 'kte'}
# Cлово -> lehnt | Возможные ошибки -> {'ehn', 'leh', 'hnt'}
# Cлово -> laengs | Возможные ошибки -> {'aen', 'lae', 'ngs', 'gs#'}
# Cлово -> sokolienitz | Возможные ошибки -> {'oko', 'sok'}
# Cлово -> befindiichen | Возможные ошибки -> {'dii', 'iic'}
# Cлово -> zieht | Возможные ошибки -> {'zie', 'eht', '#zi', 'ieh'}
# Cлово -> sehr | Возможные ошибки -> {'seh', 'ehr', 'hr#'}
# Cлово -> vortheilhaft | Возможные ошибки -> {'ilh', 'lha', 'haf'}
# Cлово -> letzteren | Возможные ошибки -> {'zte', 'tzt', 'etz'}
# Cлово -> attakiren | Возможные ошибки -> {'kir', 'tak', 'aki'}
# Cлово -> doerfer | Возможные ошибки -> {'oer', 'doe'}
# Cлово -> sokolienitz | Возможные ошибки -> {'oko', 'sok'}
# Cлово -> wodurch | Возможные ошибки -> {'odu', 'wod'}
# Cлово -> zugleich | Возможные ошибки -> {'zug', 'ugl'}
# Cлово -> ihn | Возможные ошибки -> {'#ih', 'ihn', 'hn#'}
# Cлово -> flaeche | Возможные ошибки -> {'fla', 'aec', 'lae'}
# Cлово -> zwischen | Возможные ошибки -> {'wis', 'isc', '#zw', 'zwi'}
# Cлово -> thuerassa-walde | Возможные ошибки -> {'thu', 'sa-', 'hue', 'wal', 'a-w', '-wa'}
# Cлово -> verfolgen | Возможные ошибки -> {'rfo', 'olg', 'fol', 'lge'}
# Cлово -> koennen | Возможные ошибки -> {'koe', 'oen'}
# Cлово -> defileen | Возможные ошибки -> {'een', 'lee'}
# Cлово -> bellowitz | Возможные ошибки -> {'wit', 'owi', 'low'}
# Cлово -> ausweichen | Возможные ошибки -> {'swe', 'usw'}
# Cлово -> welche | Возможные ошибки -> {'lch', 'elc'}
# Cлово -> feindliche | Возможные ошибки -> {'ndl', 'dli'}
# Cлово -> endzwecke | Возможные ошибки -> {'wec', 'ndz', 'dzw', 'zwe'}
# Cлово -> zweite | Возможные ошибки -> {'#zw', 'zwe'}
# Cлово -> дефилеи | Возможные ошибки -> {'деф', 'ефи'}
# Cлово -> буксгевден | Возможные ошибки -> {'ксг', 'сге', 'укс', 'гев'}
# Cлово -> южного | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> geographie | Возможные ошибки -> {'geo', 'eog'}
# Cлово -> школьникам-ученикам | Возможные ошибки -> {'м-у', '-уч'}
# Cлово -> государи-императоры | Возможные ошибки -> {'ри-', 'и-и'}
# Cлово -> ?.. | Возможные ошибки -> {'#?.', '?..'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> фланкёрской | Возможные ошибки -> {'нкё', 'ёрс', 'кёр'}
# Cлово -> лозунг | Возможные ошибки -> {'зун', 'унг'}
# Cлово -> рррр | Возможные ошибки -> {'ррр', '#рр', 'рр#'}
# Cлово -> ё | Возможные ошибки -> {'#ё#', '##ё'}
# Cлово -> фланкёры | Возможные ошибки -> {'нкё', 'ёры', 'кёр'}
# Cлово -> слушаю-с | Возможные ошибки -> {'ю-с', 'аю-'}
# Cлово -> бивуаки | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> 5 | Возможные ошибки -> {'##5', '#5#'}
# Cлово -> мачты | Возможные ошибки -> {'чты', 'ачт', 'мач'}
# Cлово -> то-есть | Возможные ошибки -> {'о-е', '-ес'}
# Cлово -> гольдбахом | Возможные ошибки -> {'дба', 'ьдб'}
# Cлово -> холмы | Возможные ошибки -> {'олм', 'лмы'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> холмы | Возможные ошибки -> {'олм', 'лмы'}
# Cлово -> дефилею | Возможные ошибки -> {'деф', 'ефи'}
# Cлово -> слушаю-с | Возможные ошибки -> {'ю-с', 'аю-'}
# Cлово -> dites-lui | Возможные ошибки -> {'s-l', '-lu'}
# Cлово -> demandez-lui | Возможные ошибки -> {'z-l', '-lu'}
# Cлово -> разноцветных | Возможные ошибки -> {'ноц', 'оцв'}
# Cлово -> молодцы-ординарцы | Возможные ошибки -> {'ы-о', '-ор', 'цы-'}
# Cлово -> новгородского | Возможные ошибки -> {'овг', 'вго'}
# Cлово -> марш-марш | Возможные ошибки -> {'рш-', 'ш-м'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'в-а', '-ап'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'в-а', '-ап'}
# Cлово -> ползущими | Возможные ошибки -> {'лзу', 'зущ'}
# Cлово -> 9-ть | Возможные ошибки -> {'9-т', '-ть'}
# Cлово -> аллюром | Возможные ошибки -> {'ллю', 'люр'}
# Cлово -> красавцев-людей | Возможные ошибки -> {'-лю', 'в-л', 'ев-'}
# Cлово -> рыцари | Возможные ошибки -> {'рыц', 'ыца'}
# Cлово -> по-чешски | Возможные ошибки -> {'шск', 'ешс'}
# Cлово -> обер-гофмаршал | Возможные ошибки -> {'фма', 'офм'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> плюнув | Возможные ошибки -> {'юну', 'люн'}
# Cлово -> старичок-мельник | Возможные ошибки -> {'к-м', 'ок-'}
# Cлово -> трепещущую | Возможные ошибки -> {'щущ', 'ещу', 'пещ'}
# Cлово -> рыбу | Возможные ошибки -> {'ыбу', 'рыб'}
# Cлово -> навзничь | Возможные ошибки -> {'авз', 'взн'}
# Cлово -> 19-летний | Возможные ошибки -> {'19-', '-ле', '9-л'}
# Cлово -> бивуак | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> хаос | Возможные ошибки -> {'аос', 'хао'}
# Cлово -> sujet | Возможные ошибки -> {'uje', 'suj'}

# %% [markdown]
# ### 2.2. Бор
# Далее построим бор, с помощью которого будем искать исправления опечатки в слове. Пока только в случае замены и удаления в конце (Если есть желание, то можно и для всех случаев). Также сравнить по времени с поиском в случае замены в исходном слове последних двух символов и поиске в словаре.

# %%
class TrieNode():
    def __init__(self, char):
        self.char = char
        self.children = {}
        self.end = False
        
class Trie():
    def __init__(self):
        self.root = TrieNode("")
        
    def insert(self, word):
        node = self.root
        
        for char in word:
            if char in node.children:
                node = node.children[char]
            else:
                trie_node = TrieNode(char)
                node.children[char] = trie_node
                node = trie_node
                
        node.end = True
    
    def search(self, node, prefix):
        if node.end:
            self.output.append((prefix + node.char))
            
        for child in node.children.values():
            self.search(child, prefix + node.char)
            
    def get_words(self, prefix):
        self.output = []
        node = self.root
        
        for char in prefix:
            if char in node.children:
                node = node.children[char]
            else:
                return []
        
        self.search(node, prefix[:-1])
     
        return self.output
    
    def find_similar(self, node, prefix):
        node = node
        words = []
        
        for i, char in enumerate(prefix):
            if char in node.children:
                print(node.char)
                node = node.children[char]
            else:
                print(prefix)
                print(prefix[:i - 1])
                words = self.get_words(prefix[:i])
        
        return words

# %%
trie = Trie()

for word in wordlist:
    trie.insert(word.text)

# %%
trie.find_similar(trie.root, 'зачэм')
# Out:
# з
# а
# ч
# э
# []

# %%
def call_counter(func):
    def helper(*args, **kwargs):
        helper.calls += 1
        return func(*args, **kwargs)
    helper.calls = 0
    helper.__name__= func.__name__

    return helper


memory = {}
@call_counter
def levenshtein(word1, word2):
    if word1 == "":
        return len(word2)
    if word2 == "":
        return len(word1)
    cost = 0 if word1[-1] == word2[-1] else 1
       
    i1 = (word1[:-1], word2)
    if not i1 in memory:
        memory[i1] = levenshtein(*i1)
    i2 = (word1, word2[:-1])
    if not i2 in memory:
        memory[i2] = levenshtein(*i2)
    i3 = (word1[:-1], word2[:-1])
    if not i3 in memory:
        memory[i3] = levenshtein(*i3)
    result = min([memory[i1] + 1, memory[i2] + 1, memory[i3] + cost])
    
    return result

print(levenshtein("пук-пук", "пук-хех"))
# Out:
# 3

# %%
def correct_word(word):
    return trie.get_words(word)
    
def correct_word_naive(word_to_correct, wordlist):
    distances = [(word.text, levenshtein(word_to_correct.lower(), word.text)) for word in wordlist]
    min_distance = sorted(distances, key=lambda x: x[1])[0][1]

    result = set([word[0] for word in distances if word[1] == min_distance])
    
    return list(result)[0]

# %%
word = correct_word_naive('пук', wordlist)

# %%
example = '''12-го наября кутузывская боивая армея, стаявшия лагирем окола Ольмюца, 
             гатовелась к слидующему дню на сматр двух импираторов – русського и австрейского. 
             Гвардия, только что падошедшая из России, начивала в 15-ти вирстах от Ольмюца и 
             на другай динь примо на смотр, к 10-ти чесам утра, вступала на ольмюцкое поле.'''

# %% [markdown]
# ### 2.3 Все вместе
# Теперь соберем поиск и исправление опечаток в одну систему, которая будет принимать текст и править его. Также замерим скорость по сравнению с "менее наивным подходом".

# %%
def correct_mistakes(text):
    '''returns corrected text'''
    pass

def correct_mistakes_naive(text):
    text = text.split(' ')
    for word in range(len(text)):
        text[word] = correct_word_naive(text[word], wordlist)
    
    print(' '.join(text))

# %%
# %%time

correct_mistakes_naive(example)
# Out:
# 12-го ноября кутузовская боевая армия стоявшие лагерем сокола ольмюца т т т т т т т т т т т т т готовилась к следующему дню на смотр двух императоров – русского и австрийского т т т т т т т т т т т т т гвардия только что подошедшая из россии начинала в 15-ти верстах от ольмюца и т т т т т т т т т т т т т на друга день прямо на смотр к 10-ти часам утра вступала на ольмюцкое полез
# Wall time: 35.7 s

# %% [markdown]
# С запятыми что-то пошло не так и они превратились в кучу "т", но в целом похоже на правду
