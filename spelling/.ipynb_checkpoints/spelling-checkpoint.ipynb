# %% [markdown]
# # Морфология 2
# В данном ноутбуке находится задание на триграммы и словарь. В качестве текста будем использовать томик войны и мира: https://goo.gl/qcVTLE
#
# Для начала напомним некоторые полезные инструменты на питоне

# %% [markdown]
# ## 1. Инструменты

# %% [markdown]
# ### 1.1. Регулярные выражения
# Исчерпывающий пост https://habr.com/ru/post/349860/

# %%
import re

# С помощью рег. выражения можно искать, заменять и сентезировать строки по шаблонам
# Парочка простых примеров
numbers = re.findall(r'\d+', r'There is some numbers: 49 and 432')
print(u'Находим числа в строке: ', numbers)

print(u'Простенький токенизатор: ', re.sub('[,\.?!]',' ','How, to? split. text!').split())

print(u'Еще один токенизатор: ', re.split(r'\W+', 'How, to? split. text! Again'))

# в качестве тренировки придумайте свой токенизатор в случае, когда из текста нужно получить только русские слова.
# Out:
# Находим числа в строке:  ['49', '432']
# Простенький токенизатор:  ['How', 'to', 'split', 'text']
# Еще один токенизатор:  ['How', 'to', 'split', 'text', 'Again']

# %% [markdown]
# ### 1.2. Чтение файлов
# Чтобы не мучится самим с кодировками, приведем способ чтения файла корпуса.

# %%
import io
import razdel
wordlist = None

with io.open('war_and_piece.txt', "r") as text_file:
    text = text_file.read()
    wordlist = razdel.tokenize(text.lower())
    # wordlist = Здесь заиспользуем токенизатор. Также приведем все слова к нижнему регистру.

# %% [markdown]
# ### 1.3. ООП
# В питоне можно создавать свои классы, скорее всего нам понадобится класс для хранения бора

# %%
class Trie:
    def __init__(self):
        self.children = {}
        self.is_word = False
    
    def add(self, word):
        if not word:
            print('Аргумент не является словом')
            
        head, *tail = word
        
        if head not in self.children:
            self.children[head] = Trie()
        
        node = self.children[head]
        
        if tail:
            node.add(tail)
        else:
            self.is_word = True

# %%
trie = Trie()
trie.add('he')
trie.add('she')
trie.add('his')
trie.add('hers')
trie.children
# Out:
# {'h': <__main__.Trie at 0x1cd21f0a700>, 's': <__main__.Trie at 0x1cd21f0aaf0>}

# %% [markdown]
# ### 1.4. pyplot
# Довольно часто приходится построить какие-нибудт графики и гистограммы для изучения данных, с которыми придется работать. Для этого в питоне есть удобнейший модуль для этого - pyplot. Туториал: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html

# %%
#!pip install matplotlib # Установка модуля
import matplotlib.pyplot as plt
# команда чтобы картинки рисовались прямо в ноутбуке
# %matplotlib inline

# %%
# Посмотрим на график функции x^2
data = [i * i for i in range(100)]
plt.plot(data)

# %%
# и распределение по значениям
plt.hist(data)
# Out:
# (array([32., 13., 10.,  8.,  8.,  6.,  6.,  6.,  5.,  6.]),
#  array([   0. ,  980.1, 1960.2, 2940.3, 3920.4, 4900.5, 5880.6, 6860.7,
#         7840.8, 8820.9, 9801. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Также полезная команда для подсчета времения выполнеия в ячейке

# %%
# %%time
res = 0
for i in range(int(1e8)):
    res += 1
# Out:
# Wall time: 8.87 s

# %% [markdown]
# ## 2. Задание
# Собственно теперь нам потребуется написать подсчет триграмм и бор для словаря, чтобы реализовать простенькую систему исправления ошибок.

# %% [markdown]
# ### 2.1. Триграммы
# Для начала получим словарь триграмма - её кол-во в тексте, не забывая о начале и конце слова.
#
# Далее можно построить гистограмму на кол-во вхождений триграмм, и посмотреть самые частые и какая частота у каких-нибудь заведомо странных, например: 'чгк', 'шкя' и подобные. Из полученных данных придумать эвристику, как считать слово с опечаткой. Проверить эвристику по словарю.

# %%
import io
import razdel
wordlist = None

with io.open('war_and_piece.txt', "r") as text_file:
    text = text_file.read()
    wordlist = list(razdel.tokenize(text.lower()))

# %%
def build_corpus_trigrams(words):
    trigrams_and_freq = {}
    
    for word in words:
        marked_word = '##' + word.text + '##'
        
        for char in range(len(marked_word) - 2):
            trigram = marked_word[char: char + 3]
            
            if trigram in trigrams_and_freq:
                trigrams_and_freq[trigram] += 1
            else:
                trigrams_and_freq[trigram] = 1
    
    return trigrams_and_freq

        
def is_error(word, trigrams_and_freq):
    marked_word = '##' + word.text + '##' 
    
    errors = []
    # будем учитывать две триграммы
    for char in range(1, len(marked_word) - 2):
        first_trigram = marked_word[char - 1: char + 2]
        second_trigram = marked_word[char: char + 3]
        votes = 0
        
        if first_trigram in trigrams_and_freq and trigrams_and_freq[first_trigram] > 2:
            votes += 0
        else:
            votes += 1
        
        if second_trigram in trigrams_and_freq and trigrams_and_freq[second_trigram] > 2:
            votes += 0
        else:
            votes += 1
            
        if votes == 2: 
            errors.append(first_trigram)
            errors.append(second_trigram)
            
    if errors:
        return set(errors)
    else:
        return False

# %%
def print_errors(words):
    trigram_dict = build_corpus_trigrams(words)
    for word in words:
        result = is_error(word, trigram_dict)
        if result:
            print('Cлово ->', word.text, '| Возможные ошибки ->', result)

# %%
print_errors(wordlist)
# Out:
# Cлово -> lucques | Возможные ошибки -> {'luc', 'ucq'}
# Cлово -> atrocites | Возможные ошибки -> {'roc', 'oci'}
# Cлово -> генуа | Возможные ошибки -> {'уа#', 'нуа'}
# Cлово -> лукка | Возможные ошибки -> {'кка', 'укк'}
# Cлово -> июле | Возможные ошибки -> {'#ию', 'юле', 'июл'}
# Cлово -> virulente | Возможные ошибки -> {'iru', 'vir'}
# Cлово -> insipides | Возможные ошибки -> {'sip', 'ipi'}
# Cлово -> a-t-on | Возможные ошибки -> {'t-o', '-on'}
# Cлово -> novosiizoff | Возможные ошибки -> {'ovo', 'sii', 'iiz', 'izo', 'nov'}
# Cлово -> a-t-on | Возможные ошибки -> {'t-o', '-on'}
# Cлово -> отжившим | Возможные ошибки -> {'отж', 'тжи'}
# Cлово -> гидру | Возможные ошибки -> {'гид', 'идр'}
# Cлово -> самоотвержения | Возможные ошибки -> {'моо', 'оот'}
# Cлово -> montmorency | Возможные ошибки -> {'tmo', 'cy#', 'ncy', 'ntm'}
# Cлово -> rohans | Возможные ошибки -> {'oha', 'roh'}
# Cлово -> монморанси | Возможные ошибки -> {'онм', 'нмо'}
# Cлово -> abbe | Возможные ошибки -> {'bbe', 'abb'}
# Cлово -> императрица-мать | Возможные ошибки -> {'ца-', 'а-м'}
# Cлово -> funke | Возможные ошибки -> {'fun', 'unk'}
# Cлово -> императрице-матери | Возможные ошибки -> {'е-м', 'це-'}
# Cлово -> безапелляционно | Возможные ошибки -> {'лля', 'елл'}
# Cлово -> lafater | Возможные ошибки -> {'laf', 'fat', 'afa'}
# Cлово -> 40.000 | Возможные ошибки -> {'0.0', '40.', '.00'}
# Cлово -> покой-ер-п | Возможные ошибки -> {'й-е', '-п#', '-ер', 'р-п'}
# Cлово -> шифре | Возможные ошибки -> {'ифр', 'шиф'}
# Cлово -> seduisante | Возможные ошибки -> {'sed', 'edu'}
# Cлово -> полуоткрытый | Возможные ошибки -> {'уот', 'луо'}
# Cлово -> attifee | Возможные ошибки -> {'ife', 'fee'}
# Cлово -> сыграйте | Возможные ошибки -> {'ыгр', 'сыг'}
# Cлово -> tranquille | Возможные ошибки -> {'nqu', 'anq'}
# Cлово -> красавица-княжна | Возможные ошибки -> {'а-к', '-кн', 'ца-'}
# Cлово -> сверхъестественно-прекрасное | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> сверхъестественно | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> parfait | Возможные ошибки -> {'arf', 'rfa'}
# Cлово -> b | Возможные ошибки -> {'#b#', 'b##'}
# Cлово -> ростбиф | Возможные ошибки -> {'иф#', 'биф'}
# Cлово -> hippolyte | Возможные ошибки -> {'hip', 'oly', 'yte', 'ipp', 'lyt'}
# Cлово -> сестрою-красавицей | Возможные ошибки -> {'ою-', 'ю-к'}
# Cлово -> брюзгливость | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> cuisse | Возможные ошибки -> {'#cu', 'cui'}
# Cлово -> nymphe | Возможные ошибки -> {'#ny', 'phe', 'nym', 'ymp', 'mph'}
# Cлово -> нимфы | Возможные ошибки -> {'имф', 'мфы'}
# Cлово -> george | Возможные ошибки -> {'eor', 'geo'}
# Cлово -> мадмуазель | Возможные ошибки -> {'дму', 'адм'}
# Cлово -> жорж | Возможные ошибки -> {'#жо', 'жор'}
# Cлово -> koutouzoff | Возможные ошибки -> {'uzo', 'ouz'}
# Cлово -> жорж | Возможные ошибки -> {'#жо', 'жор'}
# Cлово -> peuples | Возможные ошибки -> {'upl', 'eup'}
# Cлово -> lucques | Возможные ошибки -> {'luc', 'ucq'}
# Cлово -> лукки | Возможные ошибки -> {'кки', 'укк'}
# Cлово -> изъявляют | Возможные ошибки -> {'изъ', 'зъя'}
# Cлово -> guai | Возможные ошибки -> {'uai', 'gua'}
# Cлово -> elisabeth | Возможные ошибки -> {'th#', 'eth'}
# Cлово -> subissent | Возможные ошибки -> {'ubi', 'bis'}
# Cлово -> bourbons | Возможные ошибки -> {'urb', 'rbo'}
# Cлово -> usurpateur | Возможные ошибки -> {'urp', 'pat', '#us', 'rpa', 'usu'}
# Cлово -> azur | Возможные ошибки -> {'azu', 'zur', '#az'}
# Cлово -> геральдических | Возможные ошибки -> {'ьди', 'дич'}
# Cлово -> gloire | Возможные ошибки -> {'#gl', 'loi', 'glo'}
# Cлово -> marietyr | Возможные ошибки -> {'yr#', 'tyr', 'ety'}
# Cлово -> злоупотребления | Возможные ошибки -> {'оуп', 'лоу'}
# Cлово -> social | Возможные ошибки -> {'soc', 'cia', 'oci'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> яффе | Возможные ошибки -> {'#яф', 'яфф'}
# Cлово -> anecdote | Возможные ошибки -> {'cdo', 'ecd', 'ane', 'dot', 'nec'}
# Cлово -> moscovite | Возможные ошибки -> {'cov', 'ovi'}
# Cлово -> excusez | Возможные ошибки -> {'xcu', 'cus'}
# Cлово -> pied | Возможные ошибки -> {'ed#', 'ied'}
# Cлово -> незапно | Возможные ошибки -> {'пно', 'апн'}
# Cлово -> неуклюж | Возможные ошибки -> {'люж', 'юж#'}
# Cлово -> па-звольте | Возможные ошибки -> {'а-з', 'па-', '-зв'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'-a-', 'a-f', 't-a', '-fa'}
# Cлово -> innocent | Возможные ошибки -> {'noc', 'oce'}
# Cлово -> regnant | Возможные ошибки -> {'gna', 'egn'}
# Cлово -> гувернером-аббатом | Возможные ошибки -> {'м-а', '-аб'}
# Cлово -> свяжи | Возможные ошибки -> {'вяж', 'яжи'}
# Cлово -> образцом | Возможные ошибки -> {'зцо', 'азц'}
# Cлово -> июньская | Возможные ошибки -> {'#ию', 'ньс', 'июн', 'юнь'}
# Cлово -> бесхарактерными | Возможные ошибки -> {'сха', 'есх'}
# Cлово -> бретёр | Возможные ошибки -> {'етё', 'тёр', 'ёр#'}
# Cлово -> *** | Возможные ошибки -> {'*##', '**#', '##*', '***', '#**'}
# Cлово -> радзивилов | Возможные ошибки -> {'адз', 'дзи'}
# Cлово -> цуги | Возможные ошибки -> {'#цу', 'цуг'}
# Cлово -> камчатные | Возможные ошибки -> {'амч', 'мча'}
# Cлово -> подзывал | Возможные ошибки -> {'одз', 'дзы'}
# Cлово -> longtemps | Возможные ошибки -> {'ong', 'ngt', 'gte'}
# Cлово -> razoumowsky | Возможные ошибки -> {'mow', 'oum', 'ows', 'ky#', 'raz', 'sky', 'azo', 'umo', 'wsk'}
# Cлово -> паузе | Возможные ошибки -> {'пау', 'ауз'}
# Cлово -> медведю | Возможные ошибки -> {'едю', 'дю#'}
# Cлово -> lorrain | Возможные ошибки -> {'orr', 'lor'}
# Cлово -> гостьи-барышни | Возможные ошибки -> {'и-б', 'ьи-'}
# Cлово -> соня-племянница | Возможные ошибки -> {'-пл', 'я-п', 'ня-'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ью-', 'ю-б'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ью-', 'ю-б'}
# Cлово -> секреты-то | Возможные ошибки -> {'ы-т', 'ты-'}
# Cлово -> шепчущая | Возможные ошибки -> {'епч', 'пчу'}
# Cлово -> глубже | Возможные ошибки -> {'убж', 'бже'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'с-г', '#с-'}
# Cлово -> жанлис | Возможные ошибки -> {'нли', 'анл'}
# Cлово -> lorrain | Возможные ошибки -> {'orr', 'lor'}
# Cлово -> humanum | Возможные ошибки -> {'anu', 'num'}
# Cлово -> stupide | Возможные ошибки -> {'tup', 'upi', 'stu', '#st'}
# Cлово -> salut | Возможные ошибки -> {'lut', 'alu'}
# Cлово -> княжен-племянниц | Возможные ошибки -> {'ен-', '-пл', 'н-п'}
# Cлово -> combien | Возможные ошибки -> {'mbi', 'omb'}
# Cлово -> зачумленный | Возможные ошибки -> {'умл', 'чум'}
# Cлово -> jacquot | Возможные ошибки -> {'acq', 'jac'}
# Cлово -> jacquot | Возможные ошибки -> {'acq', 'jac'}
# Cлово -> ахросимову | Возможные ошибки -> {'ахр', 'хро'}
# Cлово -> dragon | Возможные ошибки -> {'ago', 'gon'}
# Cлово -> honorable | Возможные ошибки -> {'nor', 'ono'}
# Cлово -> альфонс | Возможные ошибки -> {'льф', 'ьфо'}
# Cлово -> карлыч | Возможные ошибки -> {'рлы', 'лыч'}
# Cлово -> нет-с | Возможные ошибки -> {'ет-', 'т-с'}
# Cлово -> двухсот | Возможные ошибки -> {'хсо', 'ухс'}
# Cлово -> двухсот | Возможные ошибки -> {'хсо', 'ухс'}
# Cлово -> roverbe | Возможные ошибки -> {'erb', 'rbe'}
# Cлово -> хозяева | Возможные ошибки -> {'зяе', 'яев'}
# Cлово -> razoumovsky | Возможные ошибки -> {'oum', 'vsk', 'ky#', 'raz', 'sky', 'ovs', 'azo', 'umo', 'mov'}
# Cлово -> яхонтовые | Возможные ошибки -> {'яхо', '#ях'}
# Cлово -> резче | Возможные ошибки -> {'езч', 'зче'}
# Cлово -> rabattu | Возможные ошибки -> {'tu#', 'ttu'}
# Cлово -> ъ | Возможные ошибки -> {'ъ##', '##ъ', '#ъ#'}
# Cлово -> ь | Возможные ошибки -> {'#ь#', '##ь'}
# Cлово -> затэм | Возможные ошибки -> {'атэ', 'тэм', 'эм#'}
# Cлово -> импэ | Возможные ошибки -> {'пэ#', 'мпэ'}
# Cлово -> знаэ | Возможные ошибки -> {'аэ#', 'наэ'}
# Cлово -> манифэ | Возможные ошибки -> {'фэ#', 'ифэ'}
# Cлово -> нэ | Возможные ошибки -> {'нэ#', '#нэ'}
# Cлово -> можэ | Возможные ошибки -> {'ожэ', 'жэ#'}
# Cлово -> смотрэт | Возможные ошибки -> {'эт#', 'трэ', 'рэт'}
# Cлово -> бэ | Возможные ошибки -> {'бэ#', '#бэ'}
# Cлово -> зачэм | Возможные ошибки -> {'ачэ', 'чэм', 'эм#'}
# Cлово -> поощрением | Возможные ошибки -> {'оощ', 'щре', 'ощр'}
# Cлово -> proverbe | Возможные ошибки -> {'erb', 'rbe'}
# Cлово -> послэ | Возможные ошибки -> {'лэ#', 'слэ'}
# Cлово -> днэ | Возможные ошибки -> {'нэ#', 'днэ'}
# Cлово -> умэ | Возможные ошибки -> {'умэ', 'мэ#'}
# Cлово -> р-р-рэ | Возможные ошибки -> {'-рэ', 'рэ#'}
# Cлово -> своэ | Возможные ошибки -> {'оэ#', 'воэ'}
# Cлово -> импэ | Возможные ошибки -> {'пэ#', 'мпэ'}
# Cлово -> всэ | Возможные ошибки -> {'всэ', 'сэ#'}
# Cлово -> й | Возможные ошибки -> {'##й', '#й#'}
# Cлово -> будэ | Возможные ошибки -> {'удэ', 'дэ#'}
# Cлово -> напыщенно | Возможные ошибки -> {'пыщ', 'ыще'}
# Cлово -> настоящэ | Возможные ошибки -> {'щэ#', 'ящэ'}
# Cлово -> й | Возможные ошибки -> {'##й', '#й#'}
# Cлово -> человэк | Возможные ошибки -> {'овэ', 'вэк'}
# Cлово -> сыграла | Возможные ошибки -> {'ыгр', 'сыг'}
# Cлово -> у-у-у | Возможные ошибки -> {'#у-', 'у-у', '-у#', '-у-'}
# Cлово -> горьче | Возможные ошибки -> {'ьче', 'рьч'}
# Cлово -> вот-вот | Возможные ошибки -> {'т-в', 'от-'}
# Cлово -> вежливостью | Возможные ошибки -> {'ежл', 'жли'}
# Cлово -> молодецки-хитрою | Возможные ошибки -> {'-хи', 'и-х'}
# Cлово -> граф-то | Возможные ошибки -> {'аф-', 'ф-т'}
# Cлово -> est-ce-pas | Возможные ошибки -> {'-pa', 'e-p'}
# Cлово -> шифоньерок | Возможные ошибки -> {'ифо', 'шиф'}
# Cлово -> шкапчиков | Возможные ошибки -> {'пчи', 'апч'}
# Cлово -> ширм | Возможные ошибки -> {'ирм', 'рм#'}
# Cлово -> нагло-шутливо | Возможные ошибки -> {'-шу', 'о-ш'}
# Cлово -> всём | Возможные ошибки -> {'сём', 'ём#'}
# Cлово -> clair | Возможные ошибки -> {'#cl', 'cla'}
# Cлово -> онуфриичем | Возможные ошибки -> {'уфр', 'нуф'}
# Cлово -> sophie | Возможные ошибки -> {'oph', 'sop'}
# Cлово -> подзывая | Возможные ошибки -> {'одз', 'дзы'}
# Cлово -> agonie | Возможные ошибки -> {'ago', 'gon'}
# Cлово -> полуосвещенную | Возможные ошибки -> {'уос', 'луо'}
# Cлово -> docteur | Возможные ошибки -> {'doc', 'oct'}
# Cлово -> a-t-il | Возможные ошибки -> {'t-i', '-il'}
# Cлово -> demi-heure | Возможные ошибки -> {'-he', 'i-h', 'mi-'}
# Cлово -> церкви | Возможные ошибки -> {'кви', 'ркв'}
# Cлово -> церкви | Возможные ошибки -> {'кви', 'ркв'}
# Cлово -> француз-доктор | Возможные ошибки -> {'з-д', 'уз-'}
# Cлово -> резче | Возможные ошибки -> {'езч', 'зче'}
# Cлово -> необычайно-широким | Возможные ошибки -> {'-ши', 'о-ш'}
# Cлово -> неуклюжее | Возможные ошибки -> {'люж', 'юже'}
# Cлово -> щипанье | Возможные ошибки -> {'#щи', 'щип'}
# Cлово -> assoupi | Возможные ошибки -> {'upi', 'pi#'}
# Cлово -> туалетах | Возможные ошибки -> {'уал', 'туа'}
# Cлово -> жемчугах | Возможные ошибки -> {'мчу', 'чуг', 'емч'}
# Cлово -> толще | Возможные ошибки -> {'олщ', 'лще'}
# Cлово -> conjure | Возможные ошибки -> {'jur', 'nju'}
# Cлово -> soutndra | Возможные ошибки -> {'tnd', 'utn'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> мадмуазель | Возможные ошибки -> {'дму', 'адм'}
# Cлово -> алгебры | Возможные ошибки -> {'геб', 'алг', 'лге'}
# Cлово -> ногтем | Возможные ошибки -> {'гте', 'огт'}
# Cлово -> элоизы | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> старчески-едким | Возможные ошибки -> {'-ед', 'и-е'}
# Cлово -> abc | Возможные ошибки -> {'bc#', 'abc'}
# Cлово -> стерпится-слюбится | Возможные ошибки -> {'ся-', 'я-с'}
# Cлово -> элоиза | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> effrayante | Возможные ошибки -> {'aya', 'yan'}
# Cлово -> indissolubles | Возможные ошибки -> {'olu', 'lub'}
# Cлово -> revolte | Возможные ошибки -> {'vol', 'olt'}
# Cлово -> puis-je | Возможные ошибки -> {'-je', 'is-', 's-j'}
# Cлово -> 211 | Возможные ошибки -> {'11#', '211', '#21'}
# Cлово -> lui-meme | Возможные ошибки -> {'i-m', 'ui-'}
# Cлово -> corsicain | Возможные ошибки -> {'ors', 'rsi'}
# Cлово -> tout-р | Возможные ошибки -> {'-р#', 't-р'}
# Cлово -> enthousiasme | Возможные ошибки -> {'tho', 'hou'}
# Cлово -> noblesse | Возможные ошибки -> {'obl', 'nob'}
# Cлово -> vingt | Возможные ошибки -> {'ngt', 'gt#'}
# Cлово -> par-dessus | Возможные ошибки -> {'ssu', 'r-d', 'sus', 'ar-'}
# Cлово -> legitime | Возможные ошибки -> {'egi', 'git', 'leg'}
# Cлово -> consequent | Возможные ошибки -> {'equ', 'seq'}
# Cлово -> legs | Возможные ошибки -> {'egs', 'leg', 'gs#'}
# Cлово -> amuse | Возможные ошибки -> {'amu', 'mus'}
# Cлово -> observer | Возможные ошибки -> {'obs', '#ob'}
# Cлово -> paru | Возможные ошибки -> {'ru#', 'aru'}
# Cлово -> amuse | Возможные ошибки -> {'amu', 'mus'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> projet | Возможные ошибки -> {'roj', 'oje'}
# Cлово -> anatole | Возможные ошибки -> {'tol', 'ato'}
# Cлово -> tombe | Возможные ошибки -> {'omb', 'tom'}
# Cлово -> choix | Возможные ошибки -> {'oix', 'hoi'}
# Cлово -> cru | Возможные ошибки -> {'ru#', 'cru'}
# Cлово -> sujet | Возможные ошибки -> {'suj', 'uje'}
# Cлово -> bavardage | Возможные ошибки -> {'rda', 'dag'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> admirable | Возможные ошибки -> {'mir', 'dmi', 'adm'}
# Cлово -> m-elle | Возможные ошибки -> {'m-e', '-el'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> поэзии | Возможные ошибки -> {'эзи', 'оэз'}
# Cлово -> свежо | Возможные ошибки -> {'жо#', 'ежо'}
# Cлово -> дочери-невесты | Возможные ошибки -> {'и-н', 'ри-'}
# Cлово -> 13 | Возможные ошибки -> {'3##', '13#', '#13'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> devrai-je | Возможные ошибки -> {'-je', 'i-j', 'ai-'}
# Cлово -> osais | Возможные ошибки -> {'osa', '#os'}
# Cлово -> avions | Возможные ошибки -> {'avi', 'vio'}
# Cлово -> ayant | Возможные ошибки -> {'aya', '#ay', 'yan'}
# Cлово -> inspire | Возможные ошибки -> {'pir', 'spi', 'nsp'}
# Cлово -> opinion | Возможные ошибки -> {'#op', 'opi'}
# Cлово -> royaume | Возможные ошибки -> {'aum', 'yau'}
# Cлово -> aura-t-il | Возможные ошибки -> {'t-i', '-il'}
# Cлово -> subir | Возможные ошибки -> {'ubi', 'bir'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> inutile | Возможные ошибки -> {'inu', 'nut'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'-a-', 'a-f', 't-a', '-fa'}
# Cлово -> chretnne | Возможные ошибки -> {'etn', 'tnn'}
# Cлово -> evangile | Возможные ошибки -> {'gil', 'ngi'}
# Cлово -> ceux-la | Возможные ошибки -> {'ux-', '-la', 'x-l'}
# Cлово -> mysterux | Возможные ошибки -> {'rux', 'eru'}
# Cлово -> etudr | Возможные ошибки -> {'etu', 'tud'}
# Cлово -> principes | Возможные ошибки -> {'pes', 'ipe'}
# Cлово -> ici-bas | Возможные ошибки -> {'ci-', '-ba', 'i-b'}
# Cлово -> persuadons-nous | Возможные ошибки -> {'sua', 'uad', 'rsu'}
# Cлово -> agreable | Возможные ошибки -> {'eab', 'rea'}
# Cлово -> rejette | Возможные ошибки -> {'rej', 'eje'}
# Cлово -> approfondir | Возможные ошибки -> {'ofo', 'rof'}
# Cлово -> plutot | Возможные ошибки -> {'uto', 'lut', 'tot'}
# Cлово -> projet | Возможные ошибки -> {'roj', 'oje'}
# Cлово -> tout-puissant | Возможные ошибки -> {'t-p', '-pu'}
# Cлово -> inquieter | Возможные ошибки -> {'inq', 'nqu'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> lequel | Возможные ошибки -> {'equ', 'leq'}
# Cлово -> sanglots | Возможные ошибки -> {'glo', 'lot'}
# Cлово -> 13-го | Возможные ошибки -> {'3-г', '13-', '#13'}
# Cлово -> juger | Возможные ошибки -> {'jug', 'uge'}
# Cлово -> дюссековой | Возможные ошибки -> {'юсс', 'дюс'}
# Cлово -> exerce | Возможные ошибки -> {'exe', 'xer'}
# Cлово -> doucement | Возможные ошибки -> {'cem', 'uce'}
# Cлово -> surprendre | Возможные ошибки -> {'urp', 'rpr'}
# Cлово -> belle-soeur | Возможные ошибки -> {'le-', 'e-s', '-so', 'soe'}
# Cлово -> мамзель | Возможные ошибки -> {'мзе', 'амз'}
# Cлово -> одынцова | Возможные ошибки -> {'ынц', 'дын'}
# Cлово -> oia | Возможные ошибки -> {'oia', '#oi', 'ia#'}
# Cлово -> брюзгливым | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> сафьяном | Возможные ошибки -> {'фья', 'саф', 'афь'}
# Cлово -> эдак | Возможные ошибки -> {'дак', '#эд', 'эда'}
# Cлово -> южная | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> malbroug | Возможные ошибки -> {'oug', 'lbr', 'alb', 'bro', 'ug#'}
# Cлово -> рюрика | Возможные ошибки -> {'юри', 'рюр'}
# Cлово -> хофс-кригс-вурст-шнапс-рат | Возможные ошибки -> {'с-р', 'ст-', 'апс', 'т-ш', 'пс-', 'с-в', '-ву', 'вур', 'гс-', '-шн'}
# Cлово -> хофс-кригс-вурст-раты | Возможные ошибки -> {'т-р', 'ст-', 'с-в', '-ву', 'вур', 'гс-'}
# Cлово -> новый-йорк | Возможные ошибки -> {'-йо', 'й-й', 'ый-'}
# Cлово -> admirateur | Возможные ошибки -> {'mir', 'dmi', 'adm'}
# Cлово -> goujat | Возможные ошибки -> {'uja', 'jat'}
# Cлово -> холопского | Возможные ошибки -> {'опс', 'пск'}
# Cлово -> покоях | Возможные ошибки -> {'оях', 'коя'}
# Cлово -> привыкшей | Возможные ошибки -> {'ыкш', 'кше'}
# Cлово -> слёз | Возможные ошибки -> {'ёз#', 'слё', 'лёз'}
# Cлово -> zouboff | Возможные ошибки -> {'ubo', 'bof'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'с-г', '#с-'}
# Cлово -> ломбардный | Возможные ошибки -> {'омб', 'мба'}
# Cлово -> bt | Возможные ошибки -> {'#bt', 'bt#'}
# Cлово -> 11-го | Возможные ошибки -> {'11-', '#11', '1-г'}
# Cлово -> как-будто | Возможные ошибки -> {'к-б', '-бу'}
# Cлово -> бесшоссейной | Возможные ошибки -> {'шос', 'сшо'}
# Cлово -> цугом | Возможные ошибки -> {'#цу', 'цуг'}
# Cлово -> кроатов | Возможные ошибки -> {'роа', 'оат'}
# Cлово -> рявкнул | Возможные ошибки -> {'явк', 'вкн'}
# Cлово -> 217 | Возможные ошибки -> {'217', '17#', '#21'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'чь-', 'ь-в', 'в-т', '-в-'}
# Cлово -> субалтерн-офицеру | Возможные ошибки -> {'н-о', 'рн-'}
# Cлово -> субалтерн-офицер | Возможные ошибки -> {'н-о', 'рн-'}
# Cлово -> федешоу | Возможные ошибки -> {'шоу', 'оу#'}
# Cлово -> турции | Возможные ошибки -> {'рци', 'урц'}
# Cлово -> солдат-песенников | Возможные ошибки -> {'ат-', 'т-п'}
# Cлово -> пляшущего | Возможные ошибки -> {'шущ', 'ляш', 'яшу'}
# Cлово -> буйному | Возможные ошибки -> {'уйн', 'буй'}
# Cлово -> фараон | Возможные ошибки -> {'аон', 'рао'}
# Cлово -> дай-ка | Возможные ошибки -> {'й-к', 'ай-'}
# Cлово -> vollkommen | Возможные ошибки -> {'kom', 'lko', 'llk'}
# Cлово -> zusammengehaltene | Возможные ошибки -> {'zus', 'amm', 'sam', 'eha', 'usa', 'geh'}
# Cлово -> krafte | Возможные ошибки -> {'raf', 'kra', '#kr'}
# Cлово -> nahe | Возможные ошибки -> {'nah', 'ahe'}
# Cлово -> angreifen | Возможные ошибки -> {'eif', 'ife'}
# Cлово -> beiden | Возможные ошибки -> {'bei', 'eid'}
# Cлово -> uferien | Возможные ошибки -> {'#uf', 'ufe'}
# Cлово -> bleiben | Возможные ошибки -> {'eib', 'ibe'}
# Cлово -> augenblick | Возможные ошибки -> {'enb', 'aug', 'nbl', 'uge'}
# Cлово -> ubersetzen | Возможные ошибки -> {'set', 'zen', '#ub', 'tze', 'etz', 'rse', 'ube'}
# Cлово -> communikations-linie | Возможные ошибки -> {'nik', 'kat', '-li', 'ika', 's-l', 'mun', 'mmu'}
# Cлово -> unterhalb | Возможные ошибки -> {'erh', 'b##', 'rha', 'alb', 'lb#'}
# Cлово -> solche | Возможные ошибки -> {'olc', 'lch'}
# Cлово -> zeitpunkt | Возможные ошибки -> {'pun', 'itp', 'nkt', '#ze', 'unk', 'tpu', 'kt#', 'zei'}
# Cлово -> kaiserlich-ruseische | Возможные ошибки -> {'-ru', '#ka', 'kai', 'ch-', 'h-r'}
# Cлово -> ausgerustet | Возможные ошибки -> {'sge', 'usg'}
# Cлово -> muthig | Возможные ошибки -> {'mut', 'uth'}
# Cлово -> entgegenharren | Возможные ошибки -> {'nha', 'ntg', 'enh', 'tge'}
# Cлово -> sodann | Возможные ошибки -> {'oda', 'sod'}
# Cлово -> gemeinschaftlich | Возможные ошибки -> {'ftl', 'tli'}
# Cлово -> moglichkeit | Возможные ошибки -> {'ogl', 'kei', 'mog', 'gli', 'chk', 'hke'}
# Cлово -> schicksal | Возможные ошибки -> {'ick', 'cks', 'ksa', 'hic'}
# Cлово -> zuzubereiten | Возможные ошибки -> {'zuz', 'uzu', 'zub', 'ube'}
# Cлово -> коммуникационную | Возможные ошибки -> {'мму', 'омм'}
# Cлово -> товарищами-сослуживцами | Возможные ошибки -> {'ми-', 'и-с'}
# Cлово -> зашибся | Возможные ошибки -> {'ибс', 'бся'}
# Cлово -> gott | Возможные ошибки -> {'got', 'tt#', 'ott'}
# Cлово -> garcon | Возможные ошибки -> {'rco', 'arc'}
# Cлово -> 11 | Возможные ошибки -> {'11#', '#11'}
# Cлово -> хозяин-немец | Возможные ошибки -> {'ин-', 'н-н'}
# Cлово -> фуфайке | Возможные ошибки -> {'фуф', 'фай', 'уфа'}
# Cлово -> oestreicher | Возможные ошибки -> {'#oe', 'oes'}
# Cлово -> kaiser | Возможные ошибки -> {'kai', '#ka'}
# Cлово -> немцем-хозяином | Возможные ошибки -> {'-хо', 'м-х'}
# Cлово -> welt | Возможные ошибки -> {'elt', 'lt#'}
# Cлово -> vivat | Возможные ошибки -> {'iva', 'vat'}
# Cлово -> welt | Возможные ошибки -> {'elt', 'lt#'}
# Cлово -> чикчиры | Возможные ошибки -> {'икч', 'кчи', 'чир'}
# Cлово -> кг | Возможные ошибки -> {'кг#', '#кг'}
# Cлово -> кг | Возможные ошибки -> {'кг#', '#кг'}
# Cлово -> правду-матку | Возможные ошибки -> {'ду-', 'у-м'}
# Cлово -> 23-го | Возможные ошибки -> {'3-г', '#23', '23-'}
# Cлово -> доппелькюмелем | Возможные ошибки -> {'кюм', 'ькю'}
# Cлово -> тащут | Возможные ошибки -> {'щут', 'ащу'}
# Cлово -> нут-ка | Возможные ошибки -> {'ут-', 'т-к'}
# Cлово -> полуулыбаясь | Возможные ошибки -> {'уул', 'луу'}
# Cлово -> подбадривает | Возможные ошибки -> {'дба', 'бад'}
# Cлово -> мундштука | Возможные ошибки -> {'дшт', 'ндш'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'чь-', 'ь-в', 'в-т', '-в-'}
# Cлово -> кое-где | Возможные ошибки -> {'е-г', '-гд'}
# Cлово -> hexo | Возможные ошибки -> {'xo#', 'exo', 'hex'}
# Cлово -> ламбахе | Возможные ошибки -> {'мба', 'амб'}
# Cлово -> амштетене | Возможные ошибки -> {'амш', 'мшт'}
# Cлово -> 28-го | Возможные ошибки -> {'8-г', '28-'}
# Cлово -> 30-го | Возможные ошибки -> {'30-', '#30'}
# Cлово -> ямщику | Возможные ошибки -> {'ямщ', 'мщи', '#ям'}
# Cлово -> hochgeboren | Возможные ошибки -> {'chg', 'geb', 'hge'}
# Cлово -> генерала-фельдмаршала | Возможные ошибки -> {'ла-', '-фе', 'а-ф'}
# Cлово -> циркуляр | Возможные ошибки -> {'ирк', '#ци', 'цир'}
# Cлово -> bilibine | Возможные ошибки -> {'ibi', 'lib'}
# Cлово -> colportaient | Возможные ошибки -> {'olp', 'lpo'}
# Cлово -> professe | Возможные ошибки -> {'ofe', 'fes', 'rof'}
# Cлово -> victoire | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> victorieuses | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> liebchen | Возможные ошибки -> {'bch', 'ebc', 'ieb'}
# Cлово -> врбна | Возможные ошибки -> {'врб', 'рбн'}
# Cлово -> лихтенфельс | Возможные ошибки -> {'нфе', 'енф'}
# Cлово -> echauffouree | Возможные ошибки -> {'ffo', 'fou'}
# Cлово -> дон-жуан | Возможные ошибки -> {'н-ж', 'уан', '-жу', 'жуа'}
# Cлово -> дон-жуан | Возможные ошибки -> {'н-ж', 'уан', '-жу', 'жуа'}
# Cлово -> majeste | Возможные ошибки -> {'jes', 'maj', 'aje'}
# Cлово -> deroge | Возможные ошибки -> {'oge', 'rog'}
# Cлово -> non-intervention | Возможные ошибки -> {'-in', 'n-i', 'on-'}
# Cлово -> imputer | Возможные ошибки -> {'mpu', 'put'}
# Cлово -> non-recevoir | Возможные ошибки -> {'ece', 'on-', 'n-r', '-re', 'cev'}
# Cлово -> tu | Возможные ошибки -> {'tu#', '#tu'}
# Cлово -> brunn | Возможные ошибки -> {'unn', 'run'}
# Cлово -> лш | Возможные ошибки -> {'лш#', '#лш'}
# Cлово -> ь | Возможные ошибки -> {'#ь#', '##ь'}
# Cлово -> маршрутов | Возможные ошибки -> {'шру', 'ршр'}
# Cлово -> з-й | Возможные ошибки -> {'з-й', '#з-'}
# Cлово -> erlaucht | Возможные ошибки -> {'rla', 'lau'}
# Cлово -> ziehen | Возможные ошибки -> {'#zi', 'zie', 'ehe', 'ieh'}
# Cлово -> bosewicht | Возможные ошибки -> {'ewi', 'sew', 'wic'}
# Cлово -> wieder | Возможные ошибки -> {'ied', 'wie'}
# Cлово -> ауэсперг | Возможные ошибки -> {'уэс', 'эсп'}
# Cлово -> нынче-завтра | Возможные ошибки -> {'че-', 'е-з'}
# Cлово -> генерал-лейтенант | Возможные ошибки -> {'-ле', 'л-л'}
# Cлово -> ногти | Возможные ошибки -> {'гти', 'огт'}
# Cлово -> heroisme | Возможные ошибки -> {'ism', 'sme'}
# Cлово -> philosophiee | Возможные ошибки -> {'hil', 'oso', 'ilo', 'oph', 'los', 'sop'}
# Cлово -> дилемма | Возможные ошибки -> {'емм', 'мма'}
# Cлово -> эцельсдорфа | Возможные ошибки -> {'рфа', '#эц', 'ьсд', 'орф', 'сдо', 'эце'}
# Cлово -> transportee | Возможные ошибки -> {'spo', 'nsp'}
# Cлово -> 7-го | Возможные ошибки -> {'7-г', '#7-'}
# Cлово -> шлюхой | Возможные ошибки -> {'юхо', 'люх'}
# Cлово -> про-пус-тить | Возможные ошибки -> {'ус-', 'с-т'}
# Cлово -> вьюки | Возможные ошибки -> {'ьюк', 'юки'}
# Cлово -> шрама | Возможные ошибки -> {'#шр', 'шра'}
# Cлово -> буксгевденом | Возможные ошибки -> {'укс', 'сге', 'гев', 'ксг'}
# Cлово -> четырехтысячный | Возможные ошибки -> {'ехт', 'хты'}
# Cлово -> schoenbrunn | Возможные ошибки -> {'hoe', 'unn', 'enb', 'nbr', 'oen', 'run'}
# Cлово -> avant-garde | Возможные ошибки -> {'-ga', 't-g'}
# Cлово -> sur-le-champ | Возможные ошибки -> {'ur-', 'r-l', '-le', 'le-'}
# Cлово -> bagage | Возможные ошибки -> {'bag', 'aga', 'gag'}
# Cлово -> celui-ci | Возможные ошибки -> {'ui-', '-ci', 'i-c'}
# Cлово -> napoleon | Возможные ошибки -> {'leo', 'eon'}
# Cлово -> 4.000-ный | Возможные ошибки -> {'.00', '#4.', '4.0', '0-н', '-ны', '00-'}
# Cлово -> алмазным | Возможные ошибки -> {'алм', 'лма'}
# Cлово -> каптенармус | Возможные ошибки -> {'апт', 'пте'}
# Cлово -> глянь-ка | Возможные ошибки -> {'нь-', 'ь-к'}
# Cлово -> хранцуз-то | Возможные ошибки -> {'з-т', 'уз-'}
# Cлово -> по-хранцузски | Возможные ошибки -> {'-хр', 'о-х'}
# Cлово -> часовой-артиллерист | Возможные ошибки -> {'й-а', '-ар'}
# Cлово -> эшелонами | Возможные ошибки -> {'эше', '#эш'}
# Cлово -> лемарруа | Возможные ошибки -> {'руа', 'уа#', 'рру'}
# Cлово -> камлотовой | Возможные ошибки -> {'амл', 'мло'}
# Cлово -> пыхтя | Возможные ошибки -> {'хтя', 'ыхт'}
# Cлово -> vaillamment | Возможные ошибки -> {'amm', 'lam'}
# Cлово -> resolument | Возможные ошибки -> {'olu', 'lum'}
# Cлово -> ceda | Возможные ошибки -> {'eda', 'ced'}
# Cлово -> штиблетах | Возможные ошибки -> {'шти', 'тиб'}
# Cлово -> оставляяй | Возможные ошибки -> {'яй#', 'яяй'}
# Cлово -> ысыо | Возможные ошибки -> {'сыо', 'ыо#'}
# Cлово -> !! | Возможные ошибки -> {'#!!', '!!#'}
# Cлово -> двухпудовая | Возможные ошибки -> {'хпу', 'ухп'}
# Cлово -> разъяренное | Возможные ошибки -> {'ъяр', 'яре', 'зъя'}
# Cлово -> подгоняя | Возможные ошибки -> {'одг', 'дго'}
# Cлово -> уцелевшие | Возможные ошибки -> {'#уц', 'уце'}
# Cлово -> солдат-артиллерист | Возможные ошибки -> {'ат-', '-ар', 'т-а'}
# Cлово -> гунтерсдорф | Возможные ошибки -> {'сдо', 'рсд'}
# Cлово -> этот-то | Возможные ошибки -> {'т-т', 'от-'}
# Cлово -> статуеобразная | Возможные ошибки -> {'уео', 'туе'}
# Cлово -> 30 | Возможные ошибки -> {'30#', '#30'}
# Cлово -> давным-давно | Возможные ошибки -> {'-да', 'м-д'}
# Cлово -> 1806 | Возможные ошибки -> {'806', '06#'}
# Cлово -> vues | Возможные ошибки -> {'vue', '#vu'}
# Cлово -> minutes | Возможные ошибки -> {'inu', 'nut', 'min'}
# Cлово -> слюни | Возможные ошибки -> {'юни', 'люн'}
# Cлово -> скрып | Возможные ошибки -> {'ып#', 'рып'}
# Cлово -> заодно | Возможные ошибки -> {'аод', 'зао'}
# Cлово -> лёлины | Возможные ошибки -> {'#лё', 'ёли', 'лёл'}
# Cлово -> ощутительнее | Возможные ошибки -> {'ощу', 'щут', '#ощ'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> — | Возможные ошибки -> {'##—', '#—#', '—##'}
# Cлово -> вызывающе-счастливой | Возможные ошибки -> {'е-с', '-сч', 'ще-'}
# Cлово -> 50 | Возможные ошибки -> {'50#', '##5', '#50'}
# Cлово -> brillant | Возможные ошибки -> {'bri', 'ril'}
# Cлово -> красавицы-жены | Возможные ошибки -> {'цы-', 'ы-ж'}
# Cлово -> крюк | Возможные ошибки -> {'крю', 'рюк', 'юк#'}
# Cлово -> рыхлую | Возможные ошибки -> {'ыхл', 'хлу'}
# Cлово -> прешпекту | Возможные ошибки -> {'шпе', 'ешп'}
# Cлово -> кх | Возможные ошибки -> {'#кх', 'кх#'}
# Cлово -> кх | Возможные ошибки -> {'#кх', 'кх#'}
# Cлово -> буфетчику | Возможные ошибки -> {'уфе', 'буф'}
# Cлово -> обжившись | Возможные ошибки -> {'обж', 'бжи'}
# Cлово -> kouraguine | Возможные ошибки -> {'uin', 'agu', 'gui'}
# Cлово -> прешпекте | Возможные ошибки -> {'шпе', 'ешп'}
# Cлово -> камзол | Возможные ошибки -> {'мзо', 'амз'}
# Cлово -> чуть-чуть | Возможные ошибки -> {'-чу', 'ь-ч'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> parfaitement | Возможные ошибки -> {'arf', 'rfa'}
# Cлово -> чудацкое | Возможные ошибки -> {'ацк', 'дац'}
# Cлово -> воля-с | Возможные ошибки -> {'ля-', 'я-с'}
# Cлово -> ха-ха-ха | Возможные ошибки -> {'ха-', '-ха', 'а-х'}
# Cлово -> один-на-один | Возможные ошибки -> {'-од', 'ин-', 'а-о', 'н-н'}
# Cлово -> diablement | Возможные ошибки -> {'iab', 'dia'}
# Cлово -> кофточке | Возможные ошибки -> {'офт', 'фто'}
# Cлово -> чепце | Возможные ошибки -> {'пце', 'епц', 'чеп'}
# Cлово -> ямами | Возможные ошибки -> {'яма', '#ям'}
# Cлово -> туфли | Возможные ошибки -> {'уфл', 'туф'}
# Cлово -> арифметической | Возможные ошибки -> {'ифм', 'риф', 'фме'}
# Cлово -> oublrai | Возможные ошибки -> {'lra', 'blr'}
# Cлово -> на-цыпочках | Возможные ошибки -> {'а-ц', '-цы'}
# Cлово -> voua | Возможные ошибки -> {'oua', 'ua#'}
# Cлово -> нюни | Возможные ошибки -> {'нюн', 'юни', '#ню'}
# Cлово -> петю | Возможные ошибки -> {'тю#', 'етю'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> миллионов-миллионов | Возможные ошибки -> {'в-м', '-ми'}
# Cлово -> образцом | Возможные ошибки -> {'зцо', 'азц'}
# Cлово -> обзаведения | Возможные ошибки -> {'бза', 'обз'}
# Cлово -> 12-го | Возможные ошибки -> {'12-', '2-г'}
# Cлово -> 15-ти | Возможные ошибки -> {'15-', '5-т'}
# Cлово -> 15-ти | Возможные ошибки -> {'15-', '5-т'}
# Cлово -> снабженные | Возможные ошибки -> {'абж', 'бже'}
# Cлово -> пирамидкой | Возможные ошибки -> {'мид', 'идк'}
# Cлово -> петизанфан | Возможные ошибки -> {'анф', 'нфа'}
# Cлово -> ущипнуть | Возможные ошибки -> {'ипн', 'щип'}
# Cлово -> армейщина | Возможные ошибки -> {'йщи', 'ейщ'}
# Cлово -> хозяевам | Возможные ошибки -> {'зяе', 'яев'}
# Cлово -> альфонс | Возможные ошибки -> {'льф', 'ьфо'}
# Cлово -> карлычем | Возможные ошибки -> {'рлы', 'лыч'}
# Cлово -> немчура | Возможные ошибки -> {'мчу', 'чур', 'емч'}
# Cлово -> свихнул | Возможные ошибки -> {'вих', 'ихн'}
# Cлово -> дуэли | Возможные ошибки -> {'дуэ', 'уэл', 'эли'}
# Cлово -> 80-титысячной | Возможные ошибки -> {'80-', '#80'}
# Cлово -> шарфах | Возможные ошибки -> {'фах', 'рфа'}
# Cлово -> расфранченные | Возможные ошибки -> {'асф', 'сфр'}
# Cлово -> аммуницией | Возможные ошибки -> {'амм', 'мму'}
# Cлово -> флюгера | Возможные ошибки -> {'люг', 'флю', 'юге'}
# Cлово -> !! | Возможные ошибки -> {'#!!', '!!#'}
# Cлово -> самоотвержения | Возможные ошибки -> {'моо', 'оот'}
# Cлово -> !? | Возможные ошибки -> {'!?#', '#!?'}
# Cлово -> замке | Возможные ошибки -> {'мке', 'амк'}
# Cлово -> аллюра | Возможные ошибки -> {'люр', 'ллю'}
# Cлово -> шварцернберга | Возможные ошибки -> {'нбе', 'рнб'}
# Cлово -> сегодняшнего | Возможные ошибки -> {'яшн', 'няш'}
# Cлово -> chef | Возможные ошибки -> {'ef#', 'hef'}
# Cлово -> пристально-холодным | Возможные ошибки -> {'-хо', 'о-х'}
# Cлово -> 16 | Возможные ошибки -> {'#16', '16#'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> huzards | Возможные ошибки -> {'uza', 'zar', 'huz'}
# Cлово -> pavlograd | Возможные ошибки -> {'vlo', 'rad', 'avl', 'ad#', 'log'}
# Cлово -> huzards | Возможные ошибки -> {'uza', 'zar', 'huz'}
# Cлово -> pavlograd | Возможные ошибки -> {'vlo', 'rad', 'avl', 'ad#', 'log'}
# Cлово -> приученная | Возможные ошибки -> {'иуч', 'риу'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> 17-го | Возможные ошибки -> {'#17', '17-', '7-г'}
# Cлово -> 19-го | Возможные ошибки -> {'19-', '9-г'}
# Cлово -> 80-титысячная | Возможные ошибки -> {'80-', '#80'}
# Cлово -> циферблате | Возможные ошибки -> {'циф', '#ци'}
# Cлово -> обер-гофмаршалу | Возможные ошибки -> {'офм', 'фма'}
# Cлово -> rr | Возможные ошибки -> {'rr#', '#rr'}
# Cлово -> wimpfen | Возможные ошибки -> {'pfe', 'mpf'}
# Cлово -> hohenloe | Возможные ошибки -> {'hoh', 'nlo', 'ohe', 'oe#', 'loe'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> noms | Возможные ошибки -> {'oms', 'ms#'}
# Cлово -> вимпфен | Возможные ошибки -> {'пфе', 'фен', 'мпф'}
# Cлово -> гогенлое | Возможные ошибки -> {'нло', 'енл'}
# Cлово -> пришпршипрш | Возможные ошибки -> {'ишп', 'ипр', 'шпр', 'прш', 'шип'}
# Cлово -> злоязычие | Возможные ошибки -> {'лоя', 'ояз'}
# Cлово -> аракчеев | Возможные ошибки -> {'чее', 'акч', 'кче'}
# Cлово -> riz | Возможные ошибки -> {'riz', 'iz#'}
# Cлово -> 8-м | Возможные ошибки -> {'8-м', '#8-'}
# Cлово -> wald | Возможные ошибки -> {'#wa', 'wal'}
# Cлово -> bedeckten | Возможные ошибки -> {'kte', 'ckt'}
# Cлово -> lehnt | Возможные ошибки -> {'hnt', 'ehn', 'leh'}
# Cлово -> laengs | Возможные ошибки -> {'gs#', 'ngs', 'aen', 'lae'}
# Cлово -> sokolienitz | Возможные ошибки -> {'oko', 'sok'}
# Cлово -> befindiichen | Возможные ошибки -> {'dii', 'iic'}
# Cлово -> zieht | Возможные ошибки -> {'#zi', 'zie', 'eht', 'ieh'}
# Cлово -> sehr | Возможные ошибки -> {'ehr', 'seh', 'hr#'}
# Cлово -> vortheilhaft | Возможные ошибки -> {'lha', 'ilh', 'haf'}
# Cлово -> letzteren | Возможные ошибки -> {'etz', 'zte', 'tzt'}
# Cлово -> attakiren | Возможные ошибки -> {'tak', 'kir', 'aki'}
# Cлово -> doerfer | Возможные ошибки -> {'oer', 'doe'}
# Cлово -> sokolienitz | Возможные ошибки -> {'oko', 'sok'}
# Cлово -> wodurch | Возможные ошибки -> {'wod', 'odu'}
# Cлово -> zugleich | Возможные ошибки -> {'ugl', 'zug'}
# Cлово -> ihn | Возможные ошибки -> {'#ih', 'hn#', 'ihn'}
# Cлово -> flaeche | Возможные ошибки -> {'fla', 'lae', 'aec'}
# Cлово -> zwischen | Возможные ошибки -> {'wis', 'isc', 'zwi', '#zw'}
# Cлово -> thuerassa-walde | Возможные ошибки -> {'wal', 'a-w', 'sa-', '-wa', 'thu', 'hue'}
# Cлово -> verfolgen | Возможные ошибки -> {'lge', 'fol', 'rfo', 'olg'}
# Cлово -> koennen | Возможные ошибки -> {'oen', 'koe'}
# Cлово -> defileen | Возможные ошибки -> {'een', 'lee'}
# Cлово -> bellowitz | Возможные ошибки -> {'wit', 'low', 'owi'}
# Cлово -> ausweichen | Возможные ошибки -> {'swe', 'usw'}
# Cлово -> welche | Возможные ошибки -> {'elc', 'lch'}
# Cлово -> feindliche | Возможные ошибки -> {'ndl', 'dli'}
# Cлово -> endzwecke | Возможные ошибки -> {'ndz', 'zwe', 'dzw', 'wec'}
# Cлово -> zweite | Возможные ошибки -> {'zwe', '#zw'}
# Cлово -> дефилеи | Возможные ошибки -> {'деф', 'ефи'}
# Cлово -> буксгевден | Возможные ошибки -> {'укс', 'сге', 'гев', 'ксг'}
# Cлово -> южного | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> geographie | Возможные ошибки -> {'eog', 'geo'}
# Cлово -> школьникам-ученикам | Возможные ошибки -> {'м-у', '-уч'}
# Cлово -> государи-императоры | Возможные ошибки -> {'и-и', 'ри-'}
# Cлово -> ?.. | Возможные ошибки -> {'?..', '#?.'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> фланкёрской | Возможные ошибки -> {'кёр', 'ёрс', 'нкё'}
# Cлово -> лозунг | Возможные ошибки -> {'зун', 'унг'}
# Cлово -> рррр | Возможные ошибки -> {'ррр', 'рр#', '#рр'}
# Cлово -> ё | Возможные ошибки -> {'##ё', '#ё#'}
# Cлово -> фланкёры | Возможные ошибки -> {'кёр', 'нкё', 'ёры'}
# Cлово -> слушаю-с | Возможные ошибки -> {'ю-с', 'аю-'}
# Cлово -> бивуаки | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> 5 | Возможные ошибки -> {'#5#', '##5'}
# Cлово -> мачты | Возможные ошибки -> {'чты', 'мач', 'ачт'}
# Cлово -> то-есть | Возможные ошибки -> {'-ес', 'о-е'}
# Cлово -> гольдбахом | Возможные ошибки -> {'ьдб', 'дба'}
# Cлово -> холмы | Возможные ошибки -> {'лмы', 'олм'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> холмы | Возможные ошибки -> {'лмы', 'олм'}
# Cлово -> дефилею | Возможные ошибки -> {'деф', 'ефи'}
# Cлово -> слушаю-с | Возможные ошибки -> {'ю-с', 'аю-'}
# Cлово -> dites-lui | Возможные ошибки -> {'s-l', '-lu'}
# Cлово -> demandez-lui | Возможные ошибки -> {'z-l', '-lu'}
# Cлово -> разноцветных | Возможные ошибки -> {'оцв', 'ноц'}
# Cлово -> молодцы-ординарцы | Возможные ошибки -> {'-ор', 'ы-о', 'цы-'}
# Cлово -> новгородского | Возможные ошибки -> {'овг', 'вго'}
# Cлово -> марш-марш | Возможные ошибки -> {'рш-', 'ш-м'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'в-а', '-ап'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'в-а', '-ап'}
# Cлово -> ползущими | Возможные ошибки -> {'зущ', 'лзу'}
# Cлово -> 9-ть | Возможные ошибки -> {'9-т', '-ть'}
# Cлово -> аллюром | Возможные ошибки -> {'люр', 'ллю'}
# Cлово -> красавцев-людей | Возможные ошибки -> {'ев-', '-лю', 'в-л'}
# Cлово -> рыцари | Возможные ошибки -> {'рыц', 'ыца'}
# Cлово -> по-чешски | Возможные ошибки -> {'шск', 'ешс'}
# Cлово -> обер-гофмаршал | Возможные ошибки -> {'офм', 'фма'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> плюнув | Возможные ошибки -> {'юну', 'люн'}
# Cлово -> старичок-мельник | Возможные ошибки -> {'к-м', 'ок-'}
# Cлово -> трепещущую | Возможные ошибки -> {'ещу', 'щущ', 'пещ'}
# Cлово -> рыбу | Возможные ошибки -> {'ыбу', 'рыб'}
# Cлово -> навзничь | Возможные ошибки -> {'авз', 'взн'}
# Cлово -> 19-летний | Возможные ошибки -> {'9-л', '-ле', '19-'}
# Cлово -> бивуак | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> хаос | Возможные ошибки -> {'аос', 'хао'}
# Cлово -> sujet | Возможные ошибки -> {'suj', 'uje'}

# %% [markdown]
# ### 2.2. Бор
# Далее построим бор, с помощью которого будем искать исправления опечатки в слове. Пока только в случае замены и удаления в конце (Если есть желание, то можно и для всех случаев). Также сравнить по времени с поиском в случае замены в исходном слове последних двух символов и поиске в словаре.

# %%
class TrieNode():
    def __init__(self, char):
        self.char = char
        self.children = {}
        self.end = False
        
class Trie():
    def __init__(self):
        self.root = TrieNode("")
        
    def insert(self, word):
        node = self.root
        
        for char in word:
            if char in node.children:
                node = node.children[char]
            else:
                trie_node = TrieNode(char)
                node.children[char] = trie_node
                node = trie_node
                
        node.end = True
    
    def search(self, node, prefix):
        if node.end:
            self.output.append((prefix + node.char))
            
        for child in node.children.values():
            self.search(child, prefix + node.char)
            
    def get_words(self, prefix):
        self.output = []
        node = self.root
        
        for char in prefix:
            if char in node.children:
                node = node.children[char]
            else:
                return []
            
        self.search(node, prefix[:-1])

        return self.output
    
    def get_simillar_words(self, prefix, errors):
        pass

# %%
trie = Trie()

for word in wordlist:
    trie.insert(word.text)

# %%
def call_counter(func):
    def helper(*args, **kwargs):
        helper.calls += 1
        return func(*args, **kwargs)
    helper.calls = 0
    helper.__name__= func.__name__

    return helper


memory = {}
@call_counter
def levenshtein(word1, word2):
    if word1 == "":
        return len(t)
    if t == "":
        return len(s)
    cost = 0 if s[-1] == t[-1] else 1
       
    i1 = (s[:-1], t)
    if not i1 in memory:
        memory[i1] = levenshtein(*i1)
    i2 = (s, t[:-1])
    if not i2 in memory:
        memory[i2] = levenshtein(*i2)
    i3 = (s[:-1], t[:-1])
    if not i3 in memory:
        memory[i3] = levenshtein(*i3)
    res = min([memory[i1] + 1, memory[i2] + 1, memory[i3] + cost])
    
    return res

print(levenshtein("каровя", "корова"))
# Out:
# 2

# %%
def correct_word(word):
    return trie.get_words(word)
    

def char_range(c1, c2):
    """Generates the characters from `c1` to `c2`, inclusive."""
    for c in range(ord(c1), ord(c2)+1):
        yield chr(c)

def correct_word_naive(word, dictionary):
    """
        Corrects word using naive approach (search most similar word in the dicitionary)
    """
    distances = [(candidate.text, levenshtein(word.lower(), candidate.text)) for candidate in dictionary]
    min_distance = sorted(distances, key=lambda x: x[1])[0][1]

    candidates = [word[0] for word in distances if word[1] == min_distance]

    return '<{}>: [{}]'.format(word, '|'.join(candidates))

# %%
correct_word_naive('коровя', wordlist)
# Out:
# '<коровя>: [короля|короля|корова]'

# %%
sample = '''лев николаевич талстой война и мип том чусть пегвая е паместья мой верный рап ну что князь генуа и лука стали не
бальше как паместьяни фамили бонапарте нет я вас предупреждааю если вы мне ни скажете что у нас вайна если вы еще позволете 
себе зашишать все гадасты все ужаси этого антихриста права я верю что он антехрест я вас больше не знаю вы уж не друх мой вы 
уш не мой верный раб как вы говориде ну здравствуйде здравствуйте я вижу что я вас пугаю садитесь и расказывайте так гаворила
в июле года известная анна павловна шерер фрейлина и'''

# %%
# %%time

correct_word_naive(wordlist, sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-12-a3a2f3a34b86> in correct_word_naive(word_dict, word)
#      17         for s in char_range('a', 'я'):
#      18             candidate = pref + f + s
# ---> 19             if candidate in word_dict:
#      20                 if f == word[-2] or s == word[-1]:
#      21                     return candidate
#
# c:\users\shkun\appdata\local\programs\python\python38\lib\site-packages\razdel\record.py in __eq__(self, other)
#      18     def __eq__(self, other):
#      19         return (
# ---> 20             type(self) == type(other)
#      21             and all(
#      22                 (getattr(self, _) == getattr(other, _))
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2.3 Все вместе
# Теперь соберем поиск и исправление опечаток в одну систему, которая будет принимать текст и править его. Также замерим скорость по сравнению с "менее наивным подходом".

# %%
def correct_mistakes(text):
    '''returns corrected text'''
    pass

def correct_mistakes_naive(text):
    '''returns corrected text using generation'''
    pass
