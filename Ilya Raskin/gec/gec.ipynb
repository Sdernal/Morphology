# %%
from converter import CoNLLConverter

# %% [markdown]
# Это самописный преобразователь датасета в нужный формат. Датасет CoNLL - это тексты со списокм ошибок. В данном случае, нам нужны всего лишь исходный текст и исправленный текст

# %%
converter = CoNLLConverter()
converter.prepare('conll14st-test-data/noalt/official-2014.0.sgml', 'source.txt', 'target.txt')

# %% [markdown]
# Теперь исходный датасет лежит в source.txt, а исправленный - в target.txt

# %% [markdown]
# Далее предполагаем, что рядом лежит склонированный репозиторий https://github.com/grammarly/gector.

# %% [markdown]
# Теперь датасет нужно преобразовать в ещё один формат. Задача GEC сводится к теггированию токенов с конечным набором тегов. Тег задаёт, какому исправлению должен подвергнуться данный токен (тег $KEEP, если токен остаётся без изменений).</br>
# Я детально изучил преобразователь в gector. Не счёл нужным писать свой, т.к. выйдет коряво и, точно, с меньшим числом поддерживаемых тегов. Да и зачем, если есть готовый.</br>

# %% [markdown]
# Если вкратце, идея такая. Сравнивается исходый текст и исправленный. Дл начала, используется difflib.SequenceMatcher.get_opcodes(). Результаты 'equal', 'insert', 'delete' становятся соответствующими метками. При этом 'insert' предполагает некоторое конечное множество возможных вставляемых слов (т.е.множество меток конечно), остальные метки независимы от токенов. Если get_opcodes возвращает 'replace', то дальше начинается длинный анализ, что это конкретно может быть за ошибка такая, и в зависимости от этого выставляется метка. В крайнем случае, может быть поставлена и просто метка $REPLACE. Согласно статье, имеется 4971 меток: "basic transformations (token-independent KEEP, DELETE and 1167 token-dependent APPEND, 3802 REPLACE) and 29 token-independent gtransformations."

# %% [markdown]
# Применяем, наконец, вышеупомянутый преобразователь датасета.

# %%
# !python3 gector/utils/preprocess_data.py -s source.txt -t target.txt -o dataset.txt
# Out:
# The size of raw dataset is 252
# 252it [00:00, 827.48it/s]
# Overall extracted 252. Original TP 237. Original TN 15

# %% [markdown]
# Ридер тоже возьмём из gector. Это логично: если преобразовали данные в текущий формат инструментом из gector, то и извлеь обратно надёжнее всего с помощью него же.</br>
# Только придётся подредактировал пути в импортах gector, т.к. там используются относительный пути:
# в datareader необходимо utils.helper исправить на gector.utils.helper

# %%
from gector.gector.datareader import Seq2LabelsDatasetReader

# %% [markdown]
# Модель возьмём из pos-tagging, только подредактируем аргументы forward, чтобы не переписывать datareader.

# %%
from model import POSTagger

# %%
import torch
from allennlp.data.vocabulary import Vocabulary
from allennlp.common import Params
from allennlp.modules.text_field_embedders import BasicTextFieldEmbedder
from allennlp.modules.token_embedders import Embedding, ElmoTokenEmbedder, TokenCharactersEncoder
from allennlp.modules.seq2seq_encoders import PytorchSeq2SeqWrapper
from allennlp.modules.seq2vec_encoders import PytorchSeq2VecWrapper
from allennlp.data.iterators import BucketIterator
from allennlp.training.trainer import Trainer
from allennlp.data.token_indexers import ELMoTokenCharactersIndexer

# %% [markdown]
# В оригинальной статье в качестве эмбеддера и энкодера использовались много раз предобучаемые и обучаемые БЕРТы. Я ограничился использованием в качестве эмеддера ELMo, т.к. во-первых, в отличие от БЕРТ-а, с ним я никогда раньше не работал, а, во-вторых, ELMo намного быстрее обучается.

# %%
reader = Seq2LabelsDatasetReader(token_indexers={'tokens': ELMoTokenCharactersIndexer()}, tn_prob=0, tp_prob=1)
dataset = reader.read('dataset.txt')
vocab = Vocabulary.from_instances(dataset, pretrained_files={'tokens':'data/cc.en.300.vec'}, only_include_pretrained_words=False)

vocab.get_index_to_token_vocabulary('labels')
# Out:
# 252it [00:00, 2956.21it/s]
# 100%|██████████| 252/252 [00:00<00:00, 18422.04it/s]
# {0: '$KEEP',
#  1: '$DELETE',
#  2: '$TRANSFORM_AGREEMENT_PLURAL',
#  3: '$TRANSFORM_VERB_VB_VBZ',
#  4: '$TRANSFORM_VERB_VBZ_VB',
#  5: '$APPEND_the',
#  6: '$APPEND_a',
#  7: '$REPLACE_a',
#  8: '$REPLACE_to',
#  9: '$REPLACE_are',
#  10: '$TRANSFORM_VERB_VBN_VB',
#  11: '$REPLACE_is',
#  12: '$TRANSFORM_CASE_CAPITAL',
#  13: '$TRANSFORM_VERB_VBG_VB',
#  14: '$TRANSFORM_VERB_VB_VBN',
#  15: '$REPLACE_the',
#  16: '$REPLACE_.',
#  17: '$TRANSFORM_CASE_LOWER',
#  18: '$TRANSFORM_VERB_VB_VBG',
#  19: '$REPLACE_in',
#  20: '$REPLACE_of',
#  21: '$REPLACE_have',
#  22: '$REPLACE_their',
#  23: '$APPEND_to',
#  24: '$REPLACE_for',
#  25: '$REPLACE_and',
#  26: '$REPLACE_they',
#  27: '$REPLACE_lives.',
#  28: '$REPLACE_be',
#  29: '$APPEND_are',
#  30: '$APPEND_that',
#  31: '$TRANSFORM_VERB_VBN_VBZ',
#  32: '$REPLACE_can',
#  33: '$APPEND_about',
#  34: '$REPLACE_with',
#  35: '$REPLACE_diseased',
#  36: '$TRANSFORM_AGREEMENT_SINGULAR',
#  37: '$APPEND_be',
#  38: '$REPLACE_about',
#  39: '$REPLACE_on',
#  40: '$REPLACE_,',
#  41: '$REPLACE_were',
#  42: '$REPLACE_has',
#  43: '$APPEND_in',
#  44: '$REPLACE_these',
#  45: '$REPLACE_them',
#  46: '$REPLACE_might',
#  47: '$REPLACE_it',
#  48: '$TRANSFORM_VERB_VBN_VBG',
#  49: '$APPEND_is',
#  50: '$APPEND_of',
#  51: '$REPLACE_from',
#  52: '$REPLACE_lives',
#  53: '$TRANSFORM_VERB_VBZ_VBN',
#  54: '$APPEND_,',
#  55: '$REPLACE_this',
#  56: '$REPLACE_find',
#  57: '$REPLACE_do',
#  58: '$REPLACE_may',
#  59: '$REPLACE_or',
#  60: '$REPLACE_there',
#  61: '$REPLACE_that',
#  62: '$REPLACE_an',
#  63: '$APPEND_have',
#  64: '$REPLACE_so',
#  65: '$APPEND_this',
#  66: '$REPLACE_genetic',
#  67: '$REPLACE_They',
#  68: '$REPLACE_was',
#  69: '$REPLACE_had',
#  70: '$REPLACE_not',
#  71: '$REPLACE_family',
#  72: '$APPEND_they',
#  73: '$APPEND_an',
#  74: '$TRANSFORM_VERB_VBZ_VBG',
#  75: '$APPEND_on',
#  76: '$APPEND_if',
#  77: '$APPEND_with',
#  78: '$APPEND_for',
#  79: '$REPLACE_need',
#  80: '$REPLACE_who',
#  81: '$REPLACE_any',
#  82: '$APPEND_which',
#  83: '$APPEND_has',
#  84: '$REPLACE_does',
#  85: '$REPLACE_become',
#  86: '$REPLACE_as',
#  87: '$REPLACE_those',
#  88: '$REPLACE_could',
#  89: '$REPLACE_social',
#  90: '$REPLACE_However,',
#  91: '$REPLACE_diseases,',
#  92: '$REPLACE_having',
#  93: '$APPEND_who',
#  94: '$REPLACE_because',
#  95: '$REPLACE_cannot',
#  96: '$REPLACE_he',
#  97: '$REPLACE_view,',
#  98: '$REPLACE_themselves',
#  99: '$REPLACE_family.',
#  100: '$REPLACE_passed',
#  101: '$REPLACE_despite',
#  102: '$REPLACE_his',
#  103: '$REPLACE_people',
#  104: '$REPLACE_believe',
#  105: '$REPLACE_should',
#  106: '$REPLACE_our',
#  107: '$APPEND_should',
#  108: '$APPEND_against',
#  109: '$REPLACE_hand,',
#  110: '$REPLACE_make',
#  111: '$REPLACE_It',
#  112: '$APPEND_can',
#  113: '$TRANSFORM_SPLIT_HYPHEN',
#  114: '$REPLACE_create',
#  115: '$REPLACE_by',
#  116: '$REPLACE_contact',
#  117: '$REPLACE_would',
#  118: '$REPLACE_at',
#  119: '$APPEND_make',
#  120: '$APPEND_it',
#  121: '$REPLACE_convenient',
#  122: '$REPLACE_used',
#  123: '$REPLACE_consider',
#  124: '$REPLACE_face',
#  125: '$REPLACE_diagnosed',
#  126: '$REPLACE_even',
#  127: '$REPLACE_entirely',
#  128: '$APPEND_as',
#  129: "$REPLACE_one's",
#  130: '$REPLACE_corresponding',
#  131: '$REPLACE_spouse',
#  132: '$REPLACE_person',
#  133: '$REPLACE_inherited',
#  134: '$REPLACE_against',
#  135: '$REPLACE_relatives',
#  136: '$APPEND_by',
#  137: '$REPLACE_receiving',
#  138: '$REPLACE_personal',
#  139: '$REPLACE_discovering',
#  140: '$REPLACE_take',
#  141: '$REPLACE_discovered',
#  142: '$REPLACE_issues,',
#  143: '$APPEND_because',
#  144: '$REPLACE_obliged',
#  145: "$REPLACE_patient's",
#  146: '$REPLACE_members',
#  147: '$REPLACE_testing',
#  148: '$APPEND_from',
#  149: '$REPLACE_if',
#  150: '$REPLACE_In',
#  151: '$REPLACE_us',
#  152: '$REPLACE_another',
#  153: '$REPLACE_hidden',
#  154: '$REPLACE_Despite',
#  155: '$REPLACE_cause',
#  156: '$APPEND_his',
#  157: '$REPLACE_ones.',
#  158: '$APPEND_could',
#  159: '$REPLACE_up',
#  160: '$REPLACE_emotional',
#  161: '$REPLACE_relatives,',
#  162: '$REPLACE_emerge',
#  163: '$REPLACE_itis',
#  164: '$REPLACE_it,',
#  165: '$REPLACE_risk',
#  166: '$APPEND_The',
#  167: '$REPLACE_worse',
#  168: '$REPLACE_days,',
#  169: '$REPLACE_made',
#  170: '$REPLACE_rights,',
#  171: '$REPLACE_scared',
#  172: '$REPLACE_mentally',
#  173: '$REPLACE_happen',
#  174: '$REPLACE_doing',
#  175: '$REPLACE_happening.',
#  176: "$REPLACE_patients'",
#  177: '$REPLACE_disease,',
#  178: '$REPLACE_ethical',
#  179: '$REPLACE_did',
#  180: '$REPLACE_how',
#  181: '$APPEND_people',
#  182: '$REPLACE_give',
#  183: '$REPLACE_feel',
#  184: '$APPEND_risk',
#  185: '$REPLACE_occur',
#  186: '$REPLACE_been',
#  187: '$REPLACE_relationships.',
#  188: '$APPEND_This',
#  189: '$REPLACE_time.',
#  190: '$TRANSFORM_VERB_VBD_VBG',
#  191: '$REPLACE_which',
#  192: '$REPLACE_times.',
#  193: '$REPLACE_People',
#  194: '$REPLACE_becoming',
#  195: '$REPLACE_front',
#  196: '$REPLACE_sharing',
#  197: '$TRANSFORM_VERB_VB_VBD',
#  198: '$APPEND_been',
#  199: '$APPEND_would',
#  200: '$REPLACE_being',
#  201: '$REPLACE_through',
#  202: '$REPLACE_pages.',
#  203: '$REPLACE_will',
#  204: '$REPLACE_beings.',
#  205: '$REPLACE_them.',
#  206: '$REPLACE_use',
#  207: '$REPLACE_statuses',
#  208: '$APPEND_social',
#  209: '$REPLACE_skills',
#  210: '$REPLACE_facilitated',
#  211: '$REPLACE_loss',
#  212: '$APPEND_rather',
#  213: '$REPLACE_less',
#  214: '$REPLACE_disadvantages.',
#  215: '$REPLACE_important',
#  216: '$REPLACE_out',
#  217: '$REPLACE_others.',
#  218: '$REPLACE_all',
#  219: '$APPEND_may',
#  220: '$REPLACE_receive',
#  221: '$REPLACE_real',
#  222: '$REPLACE_frightening',
#  223: '$REPLACE_effects',
#  224: '$REPLACE_attitude',
#  225: '$REPLACE_change,',
#  226: '$REPLACE_reducing',
#  227: '$REPLACE_exercise',
#  228: "$REPLACE_Forests'sview",
#  229: '$REPLACE_absolutely',
#  230: '$REPLACE_tell',
#  231: '$REPLACE_secrets.',
#  232: '$REPLACE_otherwise',
#  233: '$REPLACE_relative,',
#  234: '$REPLACE_individual',
#  235: '$REPLACE_debatable.',
#  236: '$REPLACE_cousins.',
#  237: '$REPLACE_concurrently',
#  238: '$REPLACE_relevant',
#  239: '$REPLACE_not.',
#  240: '$REPLACE_Does',
#  241: '$REPLACE_inform',
#  242: '$REPLACE_parentparent',
#  243: '$REPLACE_offspring',
#  244: '$APPEND_might',
#  245: '$REPLACE_perspective,',
#  246: '$REPLACE_construct,',
#  247: '$REPLACE_morality',
#  248: '$REPLACE_exercises',
#  249: '$REPLACE_burden',
#  250: '$APPEND_I',
#  251: '$REPLACE_focusing',
#  252: '$REPLACE_diseases.',
#  253: '$REPLACE_unmarried',
#  254: '$REPLACE_marrige',
#  255: '$REPLACE_issue.',
#  256: '$REPLACE_future;',
#  257: '$REPLACE_fear',
#  258: '$REPLACE_extent',
#  259: '$REPLACE_marriage,',
#  260: '$REPLACE_offspring.',
#  261: '$REPLACE_birth',
#  262: '$REPLACE_ofetoo',
#  263: "$REPLACE_carrier's",
#  264: '$REPLACE_outweighs',
#  265: '$REPLACE_exercise.',
#  266: '$REPLACE_term',
#  267: '$REPLACE_genes.',
#  268: '$REPLACE_others',
#  269: '$REPLACE_so,',
#  270: '$REPLACE_disorders?',
#  271: '$REPLACE_grandmothers',
#  272: '$REPLACE_sisters',
#  273: '$REPLACE_sons',
#  274: '$REPLACE_daughters',
#  275: '$REPLACE_and?',
#  276: '$REPLACE_developing',
#  277: '$REPLACE_potential',
#  278: '$REPLACE_too',
#  279: '$REPLACE_responsibility',
#  280: '$REPLACE_genetically',
#  281: '$REPLACE_when',
#  282: '$REPLACE_hypertention,',
#  283: '$REPLACE_blood',
#  284: '$APPEND_force',
#  285: '$REPLACE_news',
#  286: '$REPLACE_prefer',
#  287: '$REPLACE_condition.',
#  288: '$REPLACE_stages.',
#  289: '$APPEND_person',
#  290: '$REPLACE_aid',
#  291: '$REPLACE_remain',
#  292: '$APPEND_Having',
#  293: '$APPEND_difficult',
#  294: '$REPLACE_decisionbecause',
#  295: '$REPLACE_testing.',
#  296: '$REPLACE_sure',
#  297: '$REPLACE_preferable',
#  298: '$REPLACE_but',
#  299: '$REPLACE_into',
#  300: '$REPLACE_families',
#  301: '$REPLACE_play',
#  302: '$REPLACE_prevent',
#  303: '$REPLACE_similarly',
#  304: '$REPLACE_health.',
#  305: '$REPLACE_decisions',
#  306: '$REPLACE_background',
#  307: '$APPEND_whether',
#  308: '$REPLACE_disorder,,',
#  309: '$REPLACE_happy',
#  310: '$REPLACE_cared',
#  311: '$REPLACE_abnormal,',
#  312: '$REPLACE_Afterwards',
#  313: '$REPLACE_child,',
#  314: "$REPLACE_body's",
#  315: '$REPLACE_contrast,',
#  316: '$REPLACE_responsible',
#  317: "$REPLACE_Let's",
#  318: '$REPLACE_look',
#  319: '$REPLACE_possibility:',
#  320: '$REPLACE_Thus',
#  321: '$REPLACE_cultural',
#  322: '$REPLACE_backgrounds,',
#  323: '$REPLACE_increase',
#  324: '$APPEND_grow',
#  325: '$APPEND_underlying',
#  326: '$REPLACE_children.',
#  327: '$REPLACE_affected',
#  328: '$REPLACE_faced',
#  329: '$REPLACE_prosperous',
#  330: '$REPLACE_provider',
#  331: '$REPLACE_conclusion',
#  332: '$REPLACE_develop',
#  333: '$REPLACE_unlikely',
#  334: '$REPLACE_contagious.',
#  335: '$REPLACE_decision',
#  336: '$APPEND_form',
#  337: '$REPLACE_cancer',
#  338: '$REPLACE_chances',
#  339: '$REPLACE_actual',
#  340: '$REPLACE_besomething',
#  341: '$APPEND_also',
#  342: '$REPLACE_truth.',
#  343: '$APPEND_still',
#  344: '$REPLACE_tell.',
#  345: '$REPLACE_guilt',
#  346: '$APPEND_having',
#  347: '$REPLACE_difficulty.',
#  348: '$REPLACE_years:',
#  349: '$REPLACE_relatives?',
#  350: '$REPLACE_some',
#  351: '$APPEND_support',
#  352: '$REPLACE_alone.',
#  353: '$REPLACE_Ittis',
#  354: '$REPLACE_bring',
#  355: '$REPLACE_with.',
#  356: '$REPLACE_Although',
#  357: '$APPEND_decide',
#  358: '$REPLACE_stressed',
#  359: '$REPLACE_disorder.',
#  360: '$REPLACE_dilemmas.',
#  361: '$REPLACE_position',
#  362: '$REPLACE_problem:',
#  363: '$REPLACE_anxiety',
#  364: '$REPLACE_themselves.',
#  365: '$REPLACE_much',
#  366: '$APPEND_disease',
#  367: '$REPLACE_quicklyy:',
#  368: '$REPLACE_alive',
#  369: '$APPEND_hospital',
#  370: '$REPLACE_advise',
#  371: '$REPLACE_which,',
#  372: '$REPLACE_behaviour,',
#  373: '$APPEND_will',
#  374: '$APPEND_.',
#  375: '$REPLACE_disorders,',
#  376: '$REPLACE_fact',
#  377: '$REPLACE_carrier?',
#  378: '$REPLACE_diagnosed?',
#  379: '$REPLACE_my',
#  380: '$REPLACE_point',
#  381: '$APPEND_let',
#  382: '$REPLACE_pitied',
#  383: '$REPLACE_iare',
#  384: '$REPLACE_Secondly,',
#  385: '$REPLACE_ask',
#  386: '$REPLACE_problem,',
#  387: '$REPLACE_forces',
#  388: '$REPLACE_establishing',
#  389: '$REPLACE_influenceand',
#  390: '$REPLACE_e;',
#  391: '$REPLACE_difficulties',
#  392: '$REPLACE_restrict',
#  393: '$REPLACE_disorder,',
#  394: '$REPLACE_carrier',
#  395: '$REPLACE_precautions:',
#  396: '$REPLACE_offspring;',
#  397: '$REPLACE_mentally,',
#  398: '$APPEND_anything',
#  399: '$REPLACE_syndrome,',
#  400: '$REPLACE_its',
#  401: '$REPLACE_costly',
#  402: '$REPLACE_example.',
#  403: '$REPLACE_outdoors,',
#  404: '$REPLACE_high',
#  405: '$REPLACE_happening,',
#  406: '$REPLACE_clotting.',
#  407: '$REPLACE_family,',
#  408: '$REPLACE_equal',
#  409: '$REPLACE_riskto',
#  410: '$REPLACE_it.',
#  411: '$REPLACE_demonstrate',
#  412: '$REPLACE_cite',
#  413: '$REPLACE_dictum,',
#  414: '$REPLACE_cure";',
#  415: '$REPLACE_evolving.',
#  416: '$REPLACE_conduct',
#  417: '$APPEND_illness',
#  418: '$REPLACE_known,the',
#  419: '$REPLACE_preventive',
#  420: '$REPLACE_child.',
#  421: '$REPLACE_making',
#  422: '$REPLACE_pressure',
#  423: '$REPLACE_forcing',
#  424: '$REPLACE_relatives.These',
#  425: '$REPLACE_relatives;it',
#  426: '$REPLACE_wish.',
#  427: '$REPLACE_.Early',
#  428: '$APPEND_facilitates',
#  429: '$REPLACE_preventionn.',
#  430: '$REPLACE_Jolie',
#  431: '$REPLACE_story;',
#  432: '$REPLACE_Association,1980).However,',
#  433: '$REPLACE_enough',
#  434: '$APPEND_these',
#  435: '$REPLACE_Therefore',
#  436: '$REPLACE_minimum',
#  437: '$REPLACE_telling',
#  438: "$REPLACE_relatives'",
#  439: '$APPEND_their',
#  440: '$REPLACE_progressed',
#  441: '$REPLACE_addition,',
#  442: '$REPLACE_testing,',
#  443: '$REPLACE_brought',
#  444: '$REPLACE_common',
#  445: '$REPLACE_dilemma..',
#  446: '$REPLACE_For',
#  447: '$REPLACE_street,',
#  448: '$REPLACE_put',
#  449: '$REPLACE_patients',
#  450: '$REPLACE_comfortand',
#  451: '$REPLACE_help',
#  452: '$REPLACE_situations.',
#  453: '$REPLACE_words',
#  454: '$APPEND_something',
#  455: '$REPLACE_distinguish',
#  456: '$REPLACE_risk.',
#  457: '$REPLACE_disclose',
#  458: '$REPLACE_such',
#  459: '$REPLACE_disclosing',
#  460: '$REPLACE_judge',
#  461: '$REPLACE_accepted',
#  462: '$APPEND_life',
#  463: '$APPEND_care',
#  464: '$REPLACE_baggage:',
#  465: '$REPLACE_throughout',
#  466: '$REPLACE_areas',
#  467: '$REPLACE_health',
#  468: '$REPLACE_finds',
#  469: '$REPLACE_running',
#  470: '$REPLACE_Aa,',
#  471: '$MERGE_SPACE',
#  472: '$REPLACE_relatives:',
#  473: '$REPLACE_advised',
#  474: '$REPLACE_test,',
#  475: '$REPLACE_relatives;',
#  476: '$REPLACE_positive.',
#  477: '$REPLACE_cousin',
#  478: '$REPLACE_week,',
#  479: '$APPEND_A',
#  480: '$REPLACE_relatives.',
#  481: '$REPLACE_pursue',
#  482: '$REPLACE_risk,',
#  483: '$REPLACE_your',
#  484: '$REPLACE_generation,',
#  485: '$REPLACE_choice',
#  486: '$REPLACE_used.',
#  487: '$REPLACE_case:',
#  488: '$REPLACE_t',
#  489: '$REPLACE_future:',
#  490: '$REPLACE_anything.',
#  491: '$REPLACE_treat',
#  492: '$APPEND_extensive',
#  493: '$REPLACE_ways.',
#  494: '$REPLACE_warning',
#  495: '$REPLACE_genes,',
#  496: '$REPLACE_tragedy',
#  497: '$REPLACE_happened.',
#  498: '$REPLACE_First,',
#  499: '$REPLACE_seek',
#  500: '$REPLACE_Second,',
#  501: '$REPLACE_private',
#  502: '$REPLACE_people,',
#  503: '$REPLACE_him',
#  504: '$APPEND_situation',
#  505: '$REPLACE_relationship',
#  506: '$REPLACE_parents.',
#  507: '$REPLACE_know,',
#  508: '$REPLACE_anymore',
#  509: '$REPLACE_merely',
#  510: '$REPLACE_stronger.',
#  511: '$REPLACE_company',
#  512: '$APPEND_them',
#  513: '$REPLACE_Noone',
#  514: '$REPLACE_errors.',
#  515: '$APPEND_errors',
#  516: '$REPLACE_illnesses',
#  517: '$REPLACE_embarrasing',
#  518: '$REPLACE_way.',
#  519: '$REPLACE_her',
#  520: '$REPLACE_occurring.',
#  521: '$REPLACE_help.',
#  522: '$REPLACE_she',
#  523: '$REPLACE_he/she',
#  524: '$REPLACE_problem',
#  525: '$TRANSFORM_VERB_VBN_VBD',
#  526: '$REPLACE_closely.',
#  527: '$REPLACE_results.',
#  528: '$REPLACE_patient',
#  529: '$REPLACE_death.',
#  530: '$REPLACE_call',
#  531: '$REPLACE_worse.',
#  532: '$APPEND_finally',
#  533: '$REPLACE_upsetting..',
#  534: '$REPLACE_helping',
#  535: '$REPLACE_test.',
#  536: '$REPLACE_Singaporee',
#  537: '$REPLACE_hundreds',
#  538: '$REPLACE_changes',
#  539: '$REPLACE_known',
#  540: '$REPLACE_via',
#  541: '$REPLACE_humane',
#  542: '$REPLACE_convenient,',
#  543: '$REPLACE_together,',
#  544: '$REPLACE_experiences.',
#  545: '$REPLACE_luxurious',
#  546: '$TRANSFORM_VERB_VBD_VB',
#  547: '$REPLACE_beautiful',
#  548: '$REPLACE_lifestyle',
#  549: '$REPLACE_fast,',
#  550: '$REPLACE_leaves',
#  551: '$REPLACE_adapt.',
#  552: '$REPLACE_benefits;',
#  553: '$REPLACE_recipient,will',
#  554: '$REPLACE_convenience',
#  555: '$REPLACE_many',
#  556: '$REPLACE_most',
#  557: "$REPLACE_days'",
#  558: '$REPLACE_intensely',
#  559: '$REPLACE_coordination.',
#  560: '$REPLACE_necessary',
#  561: '$REPLACE_skills.',
#  562: '$REPLACE_improve',
#  563: '$REPLACE_skills,',
#  564: '$REPLACE_practices',
#  565: '$REPLACE_other.',
#  566: '$REPLACE_contrary,',
#  567: '$REPLACE_large',
#  568: '$REPLACE_base.',
#  569: '$APPEND_had',
#  570: '$REPLACE_The',
#  571: '$REPLACE_travel,',
#  572: '$REPLACE_easilyr.',
#  573: '$APPEND_even',
#  574: '$REPLACE_safeso',
#  575: "$REPLACE_others'",
#  576: '$APPEND_nature',
#  577: '$REPLACE_environmentst,',
#  578: '$REPLACE_networks',
#  579: '$REPLACE_chatting.',
#  580: '$REPLACE_world',
#  581: '$REPLACE_increasingly',
#  582: '$APPEND_media',
#  583: '$REPLACE_cheaply',
#  584: '$REPLACE_ignored',
#  585: '$REPLACE_conveniences.',
#  586: '$REPLACE_scanning',
#  587: '$APPEND_piece',
#  588: '$REPLACE_personality',
#  589: '$REPLACE_likelyto',
#  590: '$REPLACE_unhealthy',
#  591: '$REPLACE_Finally',
#  592: '$REPLACE_ever',
#  593: "$APPEND_world's",
#  594: '$REPLACE_immediately',
#  595: '$REPLACE_temporary',
#  596: '$REPLACE_closure',
#  597: '$REPLACE_relatively',
#  598: '$REPLACE_write',
#  599: '$REPLACE_ability',
#  600: '$REPLACE_posts,',
#  601: '$REPLACE_platforms.',
#  602: '$REPLACE_emotions,',
#  603: '$REPLACE_activity',
#  604: '$APPEND_does',
#  605: '$REPLACE_nowadays:',
#  606: '$REPLACE_fork;',
#  607: '$REPLACE_them;',
#  608: '$TRANSFORM_VERB_VBG_VBN',
#  609: '$REPLACE_salaried',
#  610: '$REPLACE_families.',
#  611: '$REPLACE_To',
#  612: '$REPLACE_needed',
#  613: '$REPLACE_greater.',
#  614: '$REPLACE_perhaps',
#  615: '$REPLACE_These',
#  616: '$REPLACE_complicate',
#  617: "$REPLACE_individuals'",
#  618: '$REPLACE_decreased.',
#  619: '$REPLACE_problems',
#  620: '$REPLACE_individuals,',
#  621: '$REPLACE_reflected',
#  622: '$REPLACE_quickly',
#  623: '$REPLACE_no',
#  624: '$REPLACE_stay:',
#  625: '$REPLACE_huge',
#  626: '$REPLACE_prone',
#  627: '$REPLACE_pulls',
#  628: '$REPLACE_prompts',
#  629: '$REPLACE_passes,',
#  630: '$APPEND_regard',
#  631: '$REPLACE_people:',
#  632: '$APPEND_always',
#  633: '$REPLACE_humans.',
#  634: '$REPLACE_expression,',
#  635: "$REPLACE_speaker's",
#  636: '$REPLACE_intention.',
#  637: '$REPLACE_expression',
#  638: '$REPLACE_skills".',
#  639: '$REPLACE_statistical',
#  640: '$REPLACE_spent',
#  641: "$REPLACE_'Privacy':",
#  642: '$REPLACE_over',
#  643: '$REPLACE_last',
#  644: '$REPLACE_decades..',
#  645: '$APPEND_there',
#  646: '$REPLACE_positive',
#  647: '$REPLACE_side..',
#  648: '$REPLACE_best',
#  649: '$REPLACE_obvious',
#  650: '$REPLACE_anywhere.',
#  651: '$REPLACE_keep',
#  652: '$REPLACE_broken,',
#  653: '$REPLACE_life',
#  654: '$REPLACE_over-addiction',
#  655: '$REPLACE_growing,',
#  656: '$REPLACE_situations,',
#  657: '$REPLACE_grandiose,',
#  658: '$REPLACE_addiction',
#  659: '$REPLACE_era,',
#  660: '$REPLACE_biggest',
#  661: '$REPLACE_popular,',
#  662: '$REPLACE_offered',
#  663: '$REPLACE_medium,',
#  664: '$REPLACE_Twitter',
#  665: '$REPLACE_send',
#  666: '$APPEND_quickly,',
#  667: '$REPLACE_With',
#  668: '$REPLACE_uploadedand',
#  669: '$REPLACE_published;',
#  670: '$REPLACE_Research',
#  671: '$REPLACE_reflection',
#  672: '$REPLACE_purpose:',
#  673: '$REPLACE_boundaries.',
#  674: '$REPLACE_nott',
#  675: '$REPLACE_abovee',
#  676: '$APPEND_becoming',
#  677: '$REPLACE_gadgets,',
#  678: '$REPLACE_badly',
#  679: '$REPLACE_what',
#  680: '$REPLACE_do.',
#  681: '$REPLACE_think',
#  682: '$REPLACE_disadvantage',
#  683: '$REPLACE_go',
#  684: '$REPLACE_away.',
#  685: '$REPLACE_arrive.',
#  686: '$APPEND_so',
#  687: '$REPLACE_ideas',
#  688: '$APPEND_number',
#  689: '$REPLACE_users',
#  690: '$REPLACE_humans',
#  691: '$REPLACE_Undeniably,',
#  692: '$REPLACE_addictive',
#  693: '$REPLACE_Facebookand',
#  694: '$REPLACE_effect',
#  695: '$REPLACE_interaction',
#  696: '$REPLACE_desire',
#  697: '$REPLACE_things',
#  698: '$REPLACE_advantages',
#  699: '$APPEND_disadvantages',
#  700: '$REPLACE_sites.',
#  701: '$APPEND_some',
#  702: '$REPLACE_statuses.',
#  703: '$APPEND_real',
#  704: '$REPLACE_2012:',
#  705: '$REPLACE_lie',
#  706: '$REPLACE_pretending',
#  707: '$REPLACE_occurrences',
#  708: '$REPLACE_media,',
#  709: '$REPLACE_without',
#  710: '$REPLACE_fraudulent',
#  711: '$REPLACE_superficial',
#  712: '$REPLACE_well.',
#  713: '$REPLACE_account;',
#  714: '$REPLACE_breaking',
#  715: '$REPLACE_started',
#  716: '$REPLACE_Facebook.',
#  717: '$REPLACE_shop',
#  718: '$REPLACE_trust.',
#  719: '$REPLACE_Nowadays,',
#  720: '$REPLACE_looking',
#  721: '$APPEND_at',
#  722: '$REPLACE_phonee',
#  723: '$REPLACE_trend.',
#  724: '$REPLACE_evolution.',
#  725: '$APPEND_However,',
#  726: '$APPEND_those',
#  727: '$REPLACE_sites,',
#  728: '$REPLACE_overseasaand',
#  729: '$REPLACE_friends.',
#  730: '$REPLACE_Also,',
#  731: '$REPLACE_connected..',
#  732: '$REPLACE_each',
#  733: '$REPLACE_finding',
#  734: '$REPLACE_ecultures',
#  735: '$REPLACE_online.',
#  736: '$REPLACE_Therefore,',
#  737: '$APPEND_get',
#  738: '$REPLACE_double-edged',
#  739: '$REPLACE_sword.',
#  740: '$REPLACE_lose',
#  741: '$REPLACE_written',
#  742: '$REPLACE_present',
#  743: '$REPLACE_where',
#  744: '$APPEND_together',
#  745: '$TRANSFORM_VERB_VBD_VBN',
#  746: '$REPLACE_statuses,',
#  747: '$REPLACE_looksand',
#  748: '$REPLACE_carefully',
#  749: '$REPLACE_this,',
#  750: '$REPLACE_allows',
#  751: '$REPLACE_discovered:d',
#  752: '$REPLACE_end',
#  753: '$REPLACE_interest',
#  754: '$REPLACE_extremely',
#  755: '$REPLACE_protects',
#  756: '$REPLACE_continues,',
#  757: '$REPLACE_Nobody',
#  758: '$REPLACE_time,',
#  759: '$REPLACE_difficult',
#  760: '$REPLACE_connection',
#  761: '$APPEND_true',
#  762: '$REPLACE_countries',
#  763: '$REPLACE_method',
#  764: '$REPLACE_party',
#  765: '$REPLACE_discuss',
#  766: '$REPLACE_Let',
#  767: '$REPLACE_surfing',
#  768: '$REPLACE_sites',
#  769: '$REPLACE_read',
#  770: '$REPLACE_more',
#  771: '$REPLACE_Things',
#  772: '$REPLACE_media',
#  773: '$REPLACE_Twitter,',
#  774: '$REPLACE_available,',
#  775: "$REPLACE_friend's",
#  776: '$REPLACE_society',
#  777: '$REPLACE_online',
#  778: '$REPLACE_boring',
#  779: '$APPEND_We',
#  780: '$REPLACE_recent',
#  781: '$REPLACE_enable',
#  782: '$REPLACE_express',
#  783: '$REPLACE_celebrities',
#  784: '$REPLACE_Obamaand',
#  785: '$REPLACE_these.',
#  786: '$REPLACE_influence',
#  787: '$REPLACE_face,',
#  788: '$REPLACE_important,',
#  789: '$REPLACE_others;',
#  790: '$APPEND_tell',
#  791: '$REPLACE_arise.',
#  792: '$REPLACE_Thus,,',
#  793: '$REPLACE_examine',
#  794: '$REPLACE_aspects.',
#  795: '$REPLACE_othersand',
#  796: '$REPLACE_someone,',
#  797: '$REPLACE_took',
#  798: '$APPEND_methods',
#  799: '$REPLACE_information',
#  800: '$REPLACE_membersbut',
#  801: '$REPLACE_are,',
#  802: '$REPLACE_periods',
#  803: '$REPLACE_spread',
#  804: '$APPEND_and,',
#  805: '$APPEND_though',
#  806: '$REPLACE_analysed',
#  807: '$REPLACE_paper.',
#  808: '$APPEND_There',
#  809: '$REPLACE_are.',
#  810: '$REPLACE_opportunity',
#  811: '$REPLACE_Anyone',
#  812: '$APPEND_choose',
#  813: '$REPLACE_want',
#  814: '$REPLACE_continues',
#  815: '$REPLACE_way,',
#  816: '$REPLACE_Such',
#  817: '$REPLACE_networks.',
#  818: '$REPLACE_combining'}

# %%
word_emb = 300
hidden_dim = 300

embedder = BasicTextFieldEmbedder({"tokens": ElmoTokenEmbedder(
                                      options_file='data/options.json',
                                     weight_file='data/weights.hdf5',
                                     projection_dim=word_emb)})
encoder = PytorchSeq2SeqWrapper(torch.nn.LSTM(embedder.get_output_dim(), hidden_dim, batch_first=True, bidirectional=True, num_layers=2))
model = POSTagger(vocab, embedder, encoder)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")

# %%
test_size = len(dataset) // 10
train_dataset = dataset[:-test_size]
dev_dataset = dataset[-test_size:]

# %% [markdown]
# А вот эта самая большая проблема: в датасете всего 50 текстов. Даже после разделения их на отдельные строки получается не особо много:

# %%
len(dataset)
# Out:
# 252

# %% [markdown]
# Но попробуем, других данных всё равно нет...

# %%
device = torch.device('cuda')
model.to(device)
optimizer = torch.optim.Adam(model.parameters())
iterator = BucketIterator(batch_size=16, sorting_keys=[("tokens", "num_tokens")], biggest_batch_first=True)
iterator.index_with(vocab)
trainer = Trainer(model=model,
                  optimizer=optimizer,
                  iterator=iterator,
                  train_dataset=train_dataset,
                  validation_dataset=dev_dataset,
                  patience=5,
                  num_epochs=20,
                  cuda_device=0,
                  validation_metric="+fscore")

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8353, precision: 0.8353, recall: 0.8353, fscore: 0.8353, loss: 5280.9920 ||: 100%|██████████| 15/15 [00:17<00:00,  1.13s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1695.3635 ||: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8958, precision: 0.8958, recall: 0.8958, fscore: 0.8958, loss: 1717.1580 ||: 100%|██████████| 15/15 [00:16<00:00,  1.09s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1249.4717 ||: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8964, precision: 0.8964, recall: 0.8964, fscore: 0.8964, loss: 1537.3706 ||: 100%|██████████| 15/15 [00:16<00:00,  1.09s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1241.6498 ||: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8964, precision: 0.8964, recall: 0.8964, fscore: 0.8964, loss: 1490.6402 ||: 100%|██████████| 15/15 [00:16<00:00,  1.10s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1246.4493 ||: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8964, precision: 0.8964, recall: 0.8964, fscore: 0.8964, loss: 1475.0076 ||: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1229.5849 ||: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# accuracy: 0.8964, precision: 0.8964, recall: 0.8964, fscore: 0.8964, loss: 1476.3237 ||: 100%|██████████| 15/15 [00:16<00:00,  1.11s/it]
# accuracy: 0.8462, precision: 0.8462, recall: 0.8462, fscore: 0.8462, loss: 1233.0461 ||: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
# {'best_epoch': 0,
#  'best_validation_accuracy': 0.8462316641375822,
#  'best_validation_fscore': 0.8462316393852234,
#  'best_validation_loss': 1695.3634643554688,
#  'best_validation_precision': 0.8462316393852234,
#  'best_validation_recall': 0.8462316393852234,
#  'epoch': 4,
#  'peak_cpu_memory_MB': 4371.6,
#  'peak_gpu_0_memory_MB': 14367,
#  'training_accuracy': 0.8963682268401632,
#  'training_cpu_memory_MB': 4371.6,
#  'training_duration': '0:01:30.135396',
#  'training_epochs': 4,
#  'training_fscore': 0.8963682055473328,
#  'training_gpu_0_memory_MB': 14367,
#  'training_loss': 1475.0076009114584,
#  'training_precision': 0.8963682055473328,
#  'training_recall': 0.8963682055473328,
#  'training_start_epoch': 0,
#  'validation_accuracy': 0.8462316641375822,
#  'validation_fscore': 0.8462316393852234,
#  'validation_loss': 1229.5848999023438,
#  'validation_precision': 0.8462316393852234,
#  'validation_recall': 0.8462316393852234}

# %% [markdown]
# Посмотрим...

# %%
model.eval()
with torch.no_grad():    
    labels =  model.forward_on_instance(dev_dataset[1])['labels']

for token, label in zip(dev_dataset[1]['tokens'].tokens,labels):
    print(token, label)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# $START $KEEP
# In $KEEP
# conclusion, $KEEP
# the $KEEP
# showing $KEEP
# up $KEEP
# of $KEEP
# social $KEEP
# media $KEEP
# sites $KEEP
# is $KEEP
# a $KEEP
# double $KEEP
# edged $KEEP
# sword. $KEEP
# It $KEEP
# can $KEEP
# make $KEEP
# our $KEEP
# life $KEEP
# simpler. $KEEP
# People $KEEP
# can $KEEP
# promote $KEEP
# their $KEEP
# friendship $KEEP
# and $KEEP
# relationship $KEEP
# through $KEEP
# these $KEEP
# social $KEEP
# media. $KEEP
# Whereas, $KEEP
# it $KEEP
# can $KEEP
# also $KEEP
# make $KEEP
# people $KEEP
# forget $KEEP
# to $KEEP
# communicate $KEEP
# to $KEEP
# their $KEEP
# family $KEEP
# and $KEEP
# friends $KEEP
# in $KEEP
# the $KEEP
# real $KEEP
# life $KEEP
# and $KEEP
# affect $KEEP
# negatively $KEEP
# to $KEEP
# their $KEEP
# interpersonal $KEEP
# skills. $KEEP
# But $KEEP
# overall, $KEEP
# the $KEEP
# advantages $KEEP
# far $KEEP
# outweigh $KEEP
# its $KEEP
# disadvantage. $KEEP
# So $KEEP
# we $KEEP
# need $KEEP
# to $KEEP
# make $KEEP
# best $KEEP
# use $KEEP
# of $KEEP
# these $KEEP
# social $KEEP
# media $KEEP
# and $KEEP
# make $KEEP
# it $KEEP
# a $KEEP
# fun $KEEP
# way $KEEP
# of $KEEP
# adding $KEEP
# some $KEEP
# excitement $KEEP
# when $KEEP
# life $KEEP
# is $KEEP
# boring. $KEEP
# And $KEEP
# try $KEEP
# to $KEEP
# bypass $KEEP
# the $KEEP
# shortcomings. $KEEP
# Remember $KEEP
# to $KEEP
# send $KEEP
# greetings $KEEP
# to $KEEP
# our $KEEP
# friends $KEEP
# and $KEEP
# family $KEEP
# frequently. $KEEP

# %% [markdown]
# Ну да, совсем не обучилось. Предлагает все тексты оставить как есть и не мучиться с исправлениями.

# %% [markdown]
# Немного подправленная функция из gector. Позволяет получить из исходного текста и предлагаемых исправлений исправленный текст.

# %%
from gector.utils.helpers import PAD, UNK, get_target_sent_by_edits, START_TOKEN


def get_token_action(index, sugg_token):
        """Get lost of suggested actions for token."""
        # cases when we don't need to do anything
        if sugg_token in [UNK, PAD, '$KEEP']:
            return None

        if sugg_token.startswith('$REPLACE_') or sugg_token.startswith('$TRANSFORM_') or sugg_token == '$DELETE':
            start_pos = index
            end_pos = index + 1
        elif sugg_token.startswith("$APPEND_") or sugg_token.startswith("$MERGE_"):
            start_pos = index + 1
            end_pos = index + 1

        if sugg_token == "$DELETE":
            sugg_token_clear = ""
        elif sugg_token.startswith('$TRANSFORM_') or sugg_token.startswith("$MERGE_"):
            sugg_token_clear = sugg_token[:]
        else:
            sugg_token_clear = sugg_token[sugg_token.index('_') + 1:]

        return start_pos - 1, end_pos - 1, sugg_token_clear, 0

# %%
model.eval()
with torch.no_grad():
    labels = model.forward_on_instances(dev_dataset)

for j in range(len(dev_dataset)):
    tokens = [str(i) for i in dev_dataset[j]['tokens'].tokens]
    actions = []

    for i in range(len(labels[j]['labels'])):
        action = get_token_action(i, labels[j]['labels'][i])
        if action:
            actions.append(action)

    print(' '.join(get_target_sent_by_edits(tokens, actions)[1:]))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# However, social media may do some harm to people's life. It will make people spend more time on chatting on the internet rather than communicate face to face such that the interpersonal skill will be badly affected. Some people spend a lot of time in it and forget their real life. Actually, I have seen some people are very funny and interesting when I am chatting with them online. However, they behave quite boring when I talk to them in real life. Teenagers are developing their interpersonal skills and social skills when they are growing up. If they spend too much time on these social media, it may cause some problems to their mental development. They may feel uncomfortable when they communicate with people face to face. Some may share fewer and fewer time with their family and not knowing how to express themselves. Moreover, some wrong values on the websites will affect teenagers and confuse them. Some may even do something wrong.
# In conclusion, the showing up of social media sites is a double edged sword. It can make our life simpler. People can promote their friendship and relationship through these social media. Whereas, it can also make people forget to communicate to their family and friends in the real life and affect negatively to their interpersonal skills. But overall, the advantages far outweigh its disadvantage. So we need to make best use of these social media and make it a fun way of adding some excitement when life is boring. And try to bypass the shortcomings. Remember to send greetings to our friends and family frequently.
# Nowadays, with the advancement of technology, it is easy to communicate wherever you are. The appearance of social media sites truly connects people closely. People can know their friends' recently looks and interesting things happens on that people just by checking their facebook or other social media sites. We cannot deny that the social media sites truly make the old friends do not lose the information and the chances to communicate with you even you are in a different country. However, the social media sites truly reduce the communication in face-to-face which truly affects interpersonal skills. There are two advantages and two disadvantages of using the social media in people's daily life.
# Firstly, the social media sites can connect people with their friends and parents closely. By typing the words and showing the pictures, people can express their emotions that they are too shy to express. For example, on mother's day, people are shy to say "I love you" to their mothers so they can type it on his or her mother's facebook page. Then his or her mother will also know the emotion and feel warm. On the other hand, when the teenager is studying in a foreign country, the internet is the only way that he can communicate with their parents and friends. Therefore, the social media is truly good for people.
# Secondly, the social media sites can not only connect people with their friends closely. People can also know much information about the celebrity in Twitter and Facebook such as Obama, Bill Gates and get the first-hand study materials on it. They can learn how these people succeed and they can also have the chance to talk with them and know these famous persons' thought by using the social media. On the other hand, with the help of social media, some homeless people or someone who need the money to cure the disease can get the help from the world quickly because once one person know the information, his or her will share it to their "friends area", then many people will know it and spread the information to the person who can give help.
# On the other hand, there are also problems with the population of the social media.
# Firstly, when people rely on the social media to communicate with their friends and parents, they will accustom to communicate by typing and not talking. People even prefer talk to their friends and meet their friends online and gradually reject face-to-face communication. Therefore, the social media truly limit the interpersonal skills such that people lose the chance and the ability to practice talking and connect the relation between him and their friends.
# Secondly, without the truly communication in the real life, people lose the ability to see the truth and false. There are many people in the social media with beautiful image and good content in their pages, however in real life, he or she may do not have jobs or live poorly. Teenagers may believe these people and easily be cheat and lose money even their safe. Therefore, the social media is not safe which is bad to teenager's future development.
# All in all, the appearance of social media truly helps people a lot in many areas. However, there exits some disadvantages which will affect people in some degree.
# Advantages and Disadvantages of Using Social Media in Our Daily life and Society.
# Nowadays, with the development of technology and society, social media become more popular and even important in our daily life. We communicate with others using social media, such as twitter, facebook and microblog more and more frequently. There is no need to for people to go out of their home to interact with others, they chat online, share pictures, tell others what they have done or funny stories. It seems that people build a good relationship with others by the social media, but the problems come out. Pepope do not know how to talk with others face to face, especially the strangers. Then, we need to talk about the advantages and disadvantages of using social media in your daily life and society.
# As for the advantages, there are two aspects: more convenient to contact others, easier to know about others.
# One advantage is that it is more convenience to contact others by social media. In old days, if one wants to tell some important news to another one, which lives far away, he needs to write letters and it wastes time. The long distance and time-consuming make spreading the messages very difficult at that time. Therefore, people may not contact with the faraway friends and relatives unless there are something important. However, people now can contact with anyone all over the world who can use computer at any time, and there is no time delay of messages.
# The other advantage is that it is easier to know about others by social media. If there is no social media, it is difficult for people to know about a stranger. They may collect information about that person by asking his friends, colleagues or family members. And the information collected may not be intact and true. Unlike today, with the help with social media, people can easily get the information they want just by searching on line, and know about what that person did everyday at what time.
# As for the disadvantages of social media in our daily life, wasting time, causing illness related to sitting long time before the computer, quick-spread of rumor and fake news, most importantly, making people lost the ability to talk to others face to face confidently. It is weird that people sit around the table but all face to their phones and do not talk with each other. If there is a joke on their facebook page, they may talk to others in this way, "hi, look, how ridiculous this is", then they laugh together. No matter it is a party, dinner or just simply get-together, there always are some people bow their head and playing their phones even their family and friends are in front of them.
# In a conclusion, there are both advantages and disadvantages of using social media in daily life. People should enjoy the advantages of social media while be aware of the disadvantages of that and try their best to avoid the disadvantages happen to them and their friends and family.
# Today world is considered to be the era of social media sites like Facebook and Twitter which are attractively connecting people around the world. However, some people worry that social network can affect interpersonal skills as it reduces face-to-face human contact. The advantages and disadvantages of using such social media in the society are elaborated on as follows.
# Nobody can deny social media's advantages as the benefit it provides in connecting people regardless of nationalities, races, cultures and languages. Social media is a trending channel and a suitable mean of communications.
# Firstly, social media brings convenience to the world. It has erased the boundaries of distance and time. No more worries about the time it takes to deliver letters and packages. Nowadays, thanks to the help of social media, with just one click, you can contact your family and friends wherever you want. You can share photos, videos and every meaningful experiences of your life. More importantly, it is cheap and easy to use social media.
# Secondly, social media network opens the door of opportunities for people due to its great benefit in connecting. A lot of fresh graduates can find jobs thanks to Facebook and Twitter. Young people can widen their relationships, meet new friends and learn wonderful things in many parts of the world. In business area, social media is a good tool to develop and advertise products and services.
# On the other hand, social media also has disadvantages which have created worries to the society recently and made it a controversial phenomenon. More and more young people tend to live in social media world most of their time and reduce face-to-face human contact, which can affect interpersonal skills and relationships in social life.
# First and foremost, we should realize that social media world is not trustworthy and real. Everyone can easily make up the personality and characteristics they want. They can become anyone. Though social media do create relationships, relationships and friendships are only firm and real if people have gone through experiences and communication in face-to-face interaction. There is a story of a girl who lives in social media world every night in eight years. In the chat room, she created a close relationship with eight people. She talked with them every night, trust them and share her life with them. Then eventually, she discovered that eight people became one as he was using eight different identities to chat with her all the time.
# Furthermore, the convenience of social media is also its weakness. A lot of people use their true information on social media sites, which can lead to crimes and deception. People can use the information to deceive family and friends and banks to do bad things such as blackmail, ATM theft and so on.
# Last but not least, social media does affect human interpersonal skills when people increase the time on social sites and reject chances to expose to social daily life activities as well as interacting with people. Recent research has shown that the more people spend time on social media sites, the less they become ambitious. As a result, if the situation keep go on in this unexpected trend, it will cause a bad effect on the young generation.
# To put it in the nutshell, everything has its own pros and cons. So does social media network. It not only is convenient and beneficial in connecting people and developing the business but it also can damage people relationships and interpersonal skills. Social media is only beneficial as long as we know how to use it in a correct and suitable way with the combination of both social media sites and daily life interaction to develop people's potentials to the fullest.

# %% [markdown]
# Как-то так.
